# %%
import torch as pt
import pandas as pd
import numpy as np
import pyproj as pp
import tqdm
import gc
import optuna
import atd2025

# %%
# Read dataset in
data = pd.read_csv("https://www.maserv.work/ATD/model2/ucf_atd_model/datasets/dataset1_truth.csv")
data["time"] = pd.to_datetime(data["time"])

# %%
wgs84 = pp.CRS.from_epsg(4326)
utm = pp.CRS.from_epsg(32616)
to_utm = pp.Transformer.from_crs(wgs84, utm)

rad_earth = 6371000

x, y = to_utm.transform(data["lat"].to_numpy(), data["lon"].to_numpy())

x = x.astype("float32")
y = y.astype("float32")

# Read in rest of data
t = data["time"]
t = (t - t[0]).astype("timedelta64[s]").astype("int").astype("float32")
speed = data["speed"].to_numpy().astype("float32")
course = data["course"].to_numpy().astype("float32") * np.pi / 180

x = pt.tensor(x)
y = pt.tensor(y)
t = pt.tensor(t)
dx = pt.tensor(np.sin(course) * speed)
dy = pt.tensor(np.cos(course) * speed)

gc.collect()
# Out:
# 20

# %%
def objective(trial: optuna.Trial):
    max_size = data.shape[0]
    state_size = 4

    # Keeps all tracks we have previously found
    mus = pt.zeros((max_size, state_size, 1))
    covs = pt.zeros((max_size, state_size, state_size))
    last_times = pt.zeros((max_size))
    track_id = pt.zeros((max_size), dtype=pt.long)

    # Used to keep track of where we are when filtering
    idxs = pt.arange(max_size)

    noise_x = trial.suggest_float("noise_x", 1e-3, 1000, log=True)
    noise_y = trial.suggest_float("noise_y", 1e-3, 1000, log=True)
    noise_dx = trial.suggest_float("noise_dx", 1e-3, 10, log=True)
    noise_dy = trial.suggest_float("noise_dy", 1e-3, 10, log=True)
    
    # Noise propogation constants
    qx = trial.suggest_float("qx", 1e-8, 1, log=True)
    qy = trial.suggest_float("qy", 1e-8, 1, log=True)

    # Fudge factor for maneuvers, how much of a maneuver should be allowed
    ff = trial.suggest_float("ff", 1e-3, 1 - 1e-3)

    # Man dist cutoff
    cut_dist = trial.suggest_float("cut_dist", 1e-6, 500, log=True)

    meas_noise = pt.diag(pt.tensor([noise_x, noise_dx, noise_y, noise_dy], dtype=pt.float32))
    # H = pt.zeros((state_size - 1, state_size))

    # Prior state covariance matrix
    prior_cov = (pt.eye(state_size) * 0.001)
    prior_cov[:state_size, :state_size] += meas_noise

    # Generate state transition matrix for CTRV
    def F_gen(dt, filter):
        F = pt.zeros((pt.sum(filter), state_size, state_size))
        
        # Set constants
        F[:, 0, 0] = 1
        F[:, 1, 1] = 1
        F[:, 2, 2] = 1
        F[:, 3, 3] = 1

        F[:, 0, 1] = dt
        F[:, 2, 3] = dt

        return F

    # Generate state noise matrix for CTRV
    def Q_gen(dt, filter):
        Q = pt.zeros((pt.sum(filter), state_size, state_size))
        dt3 = (dt ** 3) / 3
        dt2 = (dt ** 2) / 2
        
        Q[:, 0, 0] = qx * dt3
        Q[:, 0, 1] = qx * dt2
        Q[:, 1, 0] = qx * dt2
        Q[:, 1, 1] = qx * dt

        Q[:, 2, 2] = qy * dt3
        Q[:, 2, 3] = qy * dt2
        Q[:, 3, 2] = qy * dt2
        Q[:, 3, 3] = qy * dt

        return Q

    # Add new track to list
    def add_track(next_track_id, i):
        # Create state
        ti = t[i]
        xi = x[i]
        yi = y[i]
        dxi = dx[i]
        dyi = dy[i]

        # Update
        track_id[i] = next_track_id
        mus[next_track_id] = pt.tensor([xi, dxi, yi, dyi])[:, None]
        covs[next_track_id] = prior_cov
        last_times[next_track_id] = ti
        
    # Update an old track in the list
    def update_track(best_id, mu, cov, S, y_resid, time, i):
        # Calculate Kalman gain / intermediate value
        K = (pt.linalg.solve(S, cov)).T
        imk = pt.eye(state_size) - (K)
        
        # Calculate posterior mu/cov
        post_mu = mu + (K @ y_resid) 
        post_cov = (imk @ cov @ imk.T) + (K @ meas_noise @ K.T)

        # Update
        track_id[i] = best_id
        mus[best_id] = post_mu
        covs[best_id] = post_cov
        last_times[best_id] = time

    # Actual algorithm
    next_track_id = 0
    for i, time in tqdm.tqdm(enumerate(t), total=t.shape[0]):
        if next_track_id == 0:
            add_track(next_track_id, i)
            next_track_id += 1
            continue

        
        filter = (time - last_times[:next_track_id]) >= 2
        
        if not pt.any(filter):
            add_track(next_track_id, i)
            next_track_id += 1
            continue
        else:
            # Check best manhalobis distance, update if below threshold
            prev_times = last_times[:next_track_id][filter]
            dt = time - prev_times

            filtered_idxs = idxs[:next_track_id][filter]
            est_cov = covs[:next_track_id][filter]
            est_mu = mus[:next_track_id][filter]

            last_pos = est_mu[:, [0, 2], 0]
            curr_pos = pt.tensor([x[i], y[i]])

            dpos = pt.sqrt(pt.sum(pt.square(last_pos -  curr_pos), 1))

            fudge = pt.zeros((est_mu.shape[0]), dtype=pt.bool)

            # Allow a partial maneuver if it requires less than 35 kts velocity to make up the difference
            fudge = (dpos / dt) < 18

            # Get F and Q
            F = F_gen(dt, filter)
            Q = Q_gen(dt, filter)

            measurement = pt.tensor([x[i], dx[i], y[i], dy[i]])[:, None]

            # Get prior guess of state, allowing ff (e.g. 1/2) of the maneuver to be executed when reasonable
            new_mu = F @ est_mu
            fudged = new_mu[fudge] + ff * (measurement - new_mu[fudge])
            no_fudge = new_mu[~fudge]
            est_mu[fudge] = fudged
            est_mu[~fudge] = no_fudge
            est_cov = (F @ est_cov @ F.mT) + Q

            # Get prior guess of measurement
            est_mu_y = est_mu
            est_cov_y = est_cov + meas_noise

            # Get man dist between measurement and guess for measurement
            measurement_resid = measurement - est_mu_y
            man_dist = (measurement_resid.mT @ pt.linalg.solve(est_cov_y, measurement_resid)).squeeze()

            best_man_dist_idx = pt.argmin(man_dist)
            best_man_dist = man_dist[best_man_dist_idx]
            best_track_id = track_id[filtered_idxs[best_man_dist_idx]]
            if best_man_dist <= cut_dist:
                # Update track
                mu = est_mu[best_man_dist_idx]
                cov = est_cov[best_man_dist_idx]
                S = est_cov_y[best_man_dist_idx]
                y_resid = measurement_resid[best_man_dist_idx]
                update_track(best_track_id, mu, cov, S, y_resid, time, i)
            else:
                # New track
                add_track(next_track_id, i)
                next_track_id += 1
                continue
    
    tids = track_id.numpy()
    pids = data["point_id"]

    pd.DataFrame({"point_id": pids, "track_id": tids}).to_csv("grademe.csv")
    gc.collect()
    return atd2025.accuracy.evaluate_predictions("grademe.csv", "https://www.maserv.work/ATD/model2/ucf_atd_model/datasets/dataset1_truth.csv")

# %%
study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=100)
# Out:
# [I 2025-10-04 15:05:50,679] A new study created in memory with name: no-name-8cf7ee6c-3cca-47df-8469-0fcb8e3f7806
# 100%|██████████| 102861/102861 [01:10<00:00, 1452.62it/s]
# [I 2025-10-04 15:07:04,820] Trial 0 finished with value: 0.06549615500529841 and parameters: {'noise_x': 165.0639558305527, 'noise_y': 80.76349167588307, 'noise_dx': 9.57969905890213, 'noise_dy': 0.13712791175276134, 'qx': 9.044584268768263e-06, 'qy': 0.00016953080825203747, 'ff': 0.5644424841449784, 'cut_dist': 42.51643685091696}. Best is trial 0 with value: 0.06549615500529841.
# 100%|██████████| 102861/102861 [02:16<00:00, 755.98it/s]
# [I 2025-10-04 15:09:24,114] Trial 1 finished with value: 0.05909917266991377 and parameters: {'noise_x': 0.814886407781766, 'noise_y': 0.03792694518670703, 'noise_dx': 1.1364396004096688, 'noise_dy': 0.003286115239659765, 'qx': 5.4503449493599415e-05, 'qy': 0.14310432808029047, 'ff': 0.4153637422203479, 'cut_dist': 487.3845192365357}. Best is trial 0 with value: 0.06549615500529841.
# 100%|██████████| 102861/102861 [05:37<00:00, 304.65it/s]
# [I 2025-10-04 15:15:14,943] Trial 2 finished with value: 0.09191530317613089 and parameters: {'noise_x': 0.8977414806910127, 'noise_y': 8.443852376761164, 'noise_dx': 0.014380680046636505, 'noise_dy': 0.005211275576798006, 'qx': 0.0011241542813717894, 'qy': 0.031435560360770186, 'ff': 0.35951666859482073, 'cut_dist': 0.0019314012616965589}. Best is trial 2 with value: 0.09191530317613089.
# 100%|██████████| 102861/102861 [06:42<00:00, 255.71it/s]
# [I 2025-10-04 15:22:12,746] Trial 3 finished with value: 0.08451696950253254 and parameters: {'noise_x': 108.29946648082878, 'noise_y': 0.030209021783204434, 'noise_dx': 1.871825583031066, 'noise_dy': 1.1446540938220655, 'qx': 0.0010058712955542347, 'qy': 4.244998788321421e-05, 'ff': 0.3268751089994091, 'cut_dist': 0.001996181735725591}. Best is trial 2 with value: 0.09191530317613089.
# 100%|██████████| 102861/102861 [04:07<00:00, 414.96it/s]
# [I 2025-10-04 15:26:30,419] Trial 4 finished with value: 0.0749895490030235 and parameters: {'noise_x': 0.008959072385139516, 'noise_y': 299.6553823096487, 'noise_dx': 0.4517367715508132, 'noise_dy': 0.09058900998757408, 'qx': 0.22026980036749091, 'qy': 1.1383565977662358e-07, 'ff': 0.30363146295735377, 'cut_dist': 0.1201152866937215}. Best is trial 2 with value: 0.09191530317613089.
# 100%|██████████| 102861/102861 [07:01<00:00, 243.98it/s]
# [I 2025-10-04 15:33:51,161] Trial 5 finished with value: 0.06145672315065963 and parameters: {'noise_x': 8.546575373974264, 'noise_y': 0.001098064612061361, 'noise_dx': 2.004349444792059, 'noise_dy': 0.8040177316409364, 'qx': 0.00831639937918763, 'qy': 1.0339160911606627e-05, 'ff': 0.48751600572893117, 'cut_dist': 6.462540335146221e-06}. Best is trial 2 with value: 0.09191530317613089.
# 100%|██████████| 102861/102861 [02:12<00:00, 777.63it/s]
# [I 2025-10-04 15:36:06,754] Trial 6 finished with value: 0.061262285997608426 and parameters: {'noise_x': 238.12517613129788, 'noise_y': 47.72718107529337, 'noise_dx': 5.7640397341923615, 'noise_dy': 0.008483318697921176, 'qx': 1.3022414342590642e-05, 'qy': 0.3696270197351516, 'ff': 0.9708458193542572, 'cut_dist': 0.14522979337654932}. Best is trial 2 with value: 0.09191530317613089.
# 100%|██████████| 102861/102861 [05:24<00:00, 316.61it/s]
# [I 2025-10-04 15:41:45,199] Trial 7 finished with value: 0.08121153790066206 and parameters: {'noise_x': 2.214738569533319, 'noise_y': 1.2285918971155285, 'noise_dx': 0.007111860898701076, 'noise_dy': 2.1673093365558582, 'qx': 0.09119457504676695, 'qy': 3.1637091421396264e-06, 'ff': 0.5651506237972345, 'cut_dist': 0.000755778722449003}. Best is trial 2 with value: 0.09191530317613089.
# 100%|██████████| 102861/102861 [05:40<00:00, 302.08it/s]
# [I 2025-10-04 15:47:37,596] Trial 8 finished with value: 0.09410272114795695 and parameters: {'noise_x': 3.5187998921231762, 'noise_y': 367.4413658625486, 'noise_dx': 0.009001518178235617, 'noise_dy': 0.0021637032920277695, 'qx': 0.0004554388483685266, 'qy': 0.008063530873619416, 'ff': 0.6882916421355446, 'cut_dist': 0.002594119580241686}. Best is trial 8 with value: 0.09410272114795695.
# 100%|██████████| 102861/102861 [05:25<00:00, 316.40it/s]
# [I 2025-10-04 15:53:14,242] Trial 9 finished with value: 0.06848076530463441 and parameters: {'noise_x': 363.0032203001504, 'noise_y': 0.010337882480358522, 'noise_dx': 0.19409155689634827, 'noise_dy': 0.0017162493177777906, 'qx': 0.4618249693423787, 'qy': 8.106603234464872e-06, 'ff': 0.4665979617419534, 'cut_dist': 0.023995066980654005}. Best is trial 8 with value: 0.09410272114795695.
# 100%|██████████| 102861/102861 [08:40<00:00, 197.77it/s]
# [I 2025-10-04 16:02:15,078] Trial 10 finished with value: 0.05620205908945081 and parameters: {'noise_x': 0.011257260796189328, 'noise_y': 949.1832815333055, 'noise_dx': 0.0012375346249775701, 'noise_dy': 0.030909259042883556, 'qx': 5.6818217422728216e-08, 'qy': 0.003173702184920795, 'ff': 0.059356318008380315, 'cut_dist': 1.0152259659657129e-05}. Best is trial 8 with value: 0.09410272114795695.
# 100%|██████████| 102861/102861 [05:22<00:00, 319.11it/s]
# [I 2025-10-04 16:07:51,000] Trial 11 finished with value: 0.09360690640767638 and parameters: {'noise_x': 0.16891242707705928, 'noise_y': 4.2035238573741385, 'noise_dx': 0.025154785818335208, 'noise_dy': 0.0010066235808939103, 'qx': 0.0008574062382680402, 'qy': 0.010041740548959226, 'ff': 0.8092957950543054, 'cut_dist': 0.0001493840702716848}. Best is trial 8 with value: 0.09410272114795695.
# 100%|██████████| 102861/102861 [07:01<00:00, 244.16it/s]
# [I 2025-10-04 16:15:09,349] Trial 12 finished with value: 0.07529092659025287 and parameters: {'noise_x': 0.08989916376862561, 'noise_y': 1.3012129554375187, 'noise_dx': 0.026651871367623765, 'noise_dy': 0.0013671363463580064, 'qx': 8.599927457819455e-07, 'qy': 0.0067472718110266105, 'ff': 0.8232450804045369, 'cut_dist': 9.824189569773501e-05}. Best is trial 8 with value: 0.09410272114795695.
# 100%|██████████| 102861/102861 [02:37<00:00, 651.35it/s]
# [I 2025-10-04 16:17:50,630] Trial 13 finished with value: 0.08744324865595318 and parameters: {'noise_x': 0.07023650058283558, 'noise_y': 13.687912263389288, 'noise_dx': 0.059565467564246875, 'noise_dy': 9.41628090564143, 'qx': 0.001285689346535512, 'qy': 0.0021625951564727794, 'ff': 0.7448080047021814, 'cut_dist': 1.8149561872451436}. Best is trial 8 with value: 0.09410272114795695.
# 100%|██████████| 102861/102861 [05:52<00:00, 291.99it/s]
# [I 2025-10-04 16:23:57,425] Trial 14 finished with value: 0.0797338155374729 and parameters: {'noise_x': 13.817494772460881, 'noise_y': 0.1638656392074836, 'noise_dx': 0.004455111117126946, 'noise_dy': 0.015238669256608292, 'qx': 0.014687807342239997, 'qy': 0.00036499989335867465, 'ff': 0.71684498645802, 'cut_dist': 0.00018682888714495935}. Best is trial 8 with value: 0.09410272114795695.
# 100%|██████████| 102861/102861 [05:16<00:00, 325.26it/s]
# [I 2025-10-04 16:29:24,081] Trial 15 finished with value: 0.08941192483059664 and parameters: {'noise_x': 0.0017963965722094704, 'noise_y': 5.244853748252854, 'noise_dx': 0.001025036713569192, 'noise_dy': 0.0010740140389083734, 'qx': 0.00016209708165989655, 'qy': 0.026243879120574416, 'ff': 0.9769015066856652, 'cut_dist': 3.324106388102871e-05}. Best is trial 8 with value: 0.09410272114795695.
# 100%|██████████| 102861/102861 [07:34<00:00, 226.17it/s]
# [I 2025-10-04 16:37:17,625] Trial 16 finished with value: 0.06306569059215834 and parameters: {'noise_x': 0.15548864257730613, 'noise_y': 91.40288903320938, 'noise_dx': 0.06441921998878318, 'noise_dy': 0.04156822894875888, 'qx': 1.870608570200396e-06, 'qy': 0.7032643106172096, 'ff': 0.6885695816286873, 'cut_dist': 2.0735530121459647e-06}. Best is trial 8 with value: 0.09410272114795695.
# 100%|██████████| 102861/102861 [04:47<00:00, 357.73it/s]
# [I 2025-10-04 16:42:16,031] Trial 17 finished with value: 0.09600334431903249 and parameters: {'noise_x': 14.681257547111429, 'noise_y': 0.18501046607253196, 'noise_dx': 0.004903178647504576, 'noise_dy': 0.0035729103956759186, 'qx': 0.00013283504507883353, 'qy': 0.0008216316556044355, 'ff': 0.8468858103135538, 'cut_dist': 0.007731654355225124}. Best is trial 17 with value: 0.09600334431903249.
# 100%|██████████| 102861/102861 [05:36<00:00, 305.78it/s]
# [I 2025-10-04 16:48:06,699] Trial 18 finished with value: 0.08333576379774647 and parameters: {'noise_x': 26.98098597001845, 'noise_y': 0.08785294947613946, 'noise_dx': 0.002906678614841444, 'noise_dy': 0.011052023034394795, 'qx': 1.0003363496222614e-08, 'qy': 0.0006685806186168276, 'ff': 0.8647903600214092, 'cut_dist': 0.015243196449387392}. Best is trial 17 with value: 0.09600334431903249.
# 100%|██████████| 102861/102861 [05:20<00:00, 320.90it/s]
# [I 2025-10-04 16:53:36,933] Trial 19 finished with value: 0.0865099503213074 and parameters: {'noise_x': 4.267481227426564, 'noise_y': 0.32869782177738555, 'noise_dx': 0.009070262798558803, 'noise_dy': 0.0037212040527438033, 'qx': 0.00012607638713753463, 'qy': 3.504527751315412e-07, 'ff': 0.6207648069669064, 'cut_dist': 3.1552153392061046}. Best is trial 17 with value: 0.09600334431903249.
# 100%|██████████| 102861/102861 [05:05<00:00, 337.12it/s]
# [I 2025-10-04 16:58:55,792] Trial 20 finished with value: 0.08066711387211868 and parameters: {'noise_x': 44.01307917541273, 'noise_y': 0.008013016433460309, 'noise_dx': 0.002233128060476706, 'noise_dy': 0.24940497887638513, 'qx': 0.009883557465293007, 'qy': 1.462192599884694e-08, 'ff': 0.09983988795394921, 'cut_dist': 0.021028169372300384}. Best is trial 17 with value: 0.09600334431903249.
# 100%|██████████| 102861/102861 [05:23<00:00, 318.11it/s]
# [I 2025-10-04 17:04:30,766] Trial 21 finished with value: 0.09111324991979468 and parameters: {'noise_x': 0.3490290146478637, 'noise_y': 0.5025342787548478, 'noise_dx': 0.023475579270965087, 'noise_dy': 0.002727380884987982, 'qx': 0.0002985379091751979, 'qy': 0.0278152640174919, 'ff': 0.8428389335388655, 'cut_dist': 0.0005247136251272833}. Best is trial 17 with value: 0.09600334431903249.
# 100%|██████████| 102861/102861 [04:38<00:00, 369.14it/s]
# [I 2025-10-04 17:09:20,765] Trial 22 finished with value: 0.09490477440429317 and parameters: {'noise_x': 2.6255367089648334, 'noise_y': 3.0652567733216056, 'noise_dx': 0.03534041102821145, 'noise_dy': 0.0012697038223600814, 'qx': 2.529001785675477e-05, 'qy': 0.0012902925024694493, 'ff': 0.8960291202903949, 'cut_dist': 0.003932831112260051}. Best is trial 17 with value: 0.09600334431903249.
# 100%|██████████| 102861/102861 [06:14<00:00, 274.99it/s]
# [I 2025-10-04 17:15:46,987] Trial 23 finished with value: 0.1052925793060538 and parameters: {'noise_x': 852.2463345787793, 'noise_y': 27.74421602943421, 'noise_dx': 0.15610042552367298, 'noise_dy': 0.024861662309320055, 'qx': 1.6450580335323376e-05, 'qy': 4.7442670259004464e-05, 'ff': 0.9228175356243128, 'cut_dist': 0.005020516848458151}. Best is trial 23 with value: 0.1052925793060538.
# 100%|██████████| 102861/102861 [04:36<00:00, 372.66it/s]
# [I 2025-10-04 17:20:28,791] Trial 24 finished with value: 0.10295933346943933 and parameters: {'noise_x': 56.94195263279268, 'noise_y': 24.623071855666357, 'noise_dx': 0.16356584215337996, 'noise_dy': 0.02131202164987239, 'qx': 1.7532602067933466e-05, 'qy': 5.033647930941296e-05, 'ff': 0.9241531517983529, 'cut_dist': 0.2216198179343774}. Best is trial 23 with value: 0.1052925793060538.
# 100%|██████████| 102861/102861 [02:18<00:00, 744.08it/s]
# [I 2025-10-04 17:22:50,199] Trial 25 finished with value: 0.07211674006669194 and parameters: {'noise_x': 704.8182722647547, 'noise_y': 21.403896256550876, 'noise_dx': 0.19521451573249993, 'noise_dy': 0.02420382712990171, 'qx': 3.0962613959743697e-06, 'qy': 5.226280535299463e-05, 'ff': 0.9911855460108584, 'cut_dist': 0.5338504366515407}. Best is trial 23 with value: 0.1052925793060538.
# 100%|██████████| 102861/102861 [05:00<00:00, 342.46it/s]
# [I 2025-10-04 17:28:00,398] Trial 26 finished with value: 0.09662068227997006 and parameters: {'noise_x': 903.6683389552323, 'noise_y': 29.455261718379607, 'noise_dx': 0.1575189188116606, 'noise_dy': 0.06479364198036586, 'qx': 1.825563377611025e-07, 'qy': 1.02185983901013e-06, 'ff': 0.912278785614342, 'cut_dist': 0.10952001807088216}. Best is trial 23 with value: 0.1052925793060538.
# 100%|██████████| 102861/102861 [02:20<00:00, 734.38it/s]
# [I 2025-10-04 17:30:23,662] Trial 27 finished with value: 0.06744538746463674 and parameters: {'noise_x': 596.411501981766, 'noise_y': 23.461301130408994, 'noise_dx': 0.1502534101309705, 'noise_dy': 0.06395952317215838, 'qx': 3.498562098678837e-07, 'qy': 6.35141801518915e-07, 'ff': 0.9244749332234117, 'cut_dist': 10.855405673499948}. Best is trial 23 with value: 0.1052925793060538.
# 100%|██████████| 102861/102861 [06:08<00:00, 279.13it/s]
# [I 2025-10-04 17:36:45,813] Trial 28 finished with value: 0.10554048667619409 and parameters: {'noise_x': 57.52375628010918, 'noise_y': 139.58521055889582, 'noise_dx': 0.6982433740413194, 'noise_dy': 0.26622874039362826, 'qx': 1.3901912246705402e-07, 'qy': 1.841627006661118e-06, 'ff': 0.1845912717707725, 'cut_dist': 0.09337597502078247}. Best is trial 28 with value: 0.10554048667619409.
# 100%|██████████| 102861/102861 [04:27<00:00, 384.89it/s]
# [I 2025-10-04 17:41:23,927] Trial 29 finished with value: 0.10721264619243445 and parameters: {'noise_x': 72.66894819283495, 'noise_y': 143.38870561691266, 'noise_dx': 0.7337654901971735, 'noise_dy': 0.15237791768027534, 'qx': 4.628923059484107e-06, 'qy': 0.00013202121450058406, 'ff': 0.2104792532057853, 'cut_dist': 0.5238402575689043}. Best is trial 29 with value: 0.10721264619243445.
# 100%|██████████| 102861/102861 [01:59<00:00, 863.60it/s]
# [I 2025-10-04 17:43:26,469] Trial 30 finished with value: 0.07860608004977591 and parameters: {'noise_x': 130.78118531251945, 'noise_y': 129.95952947222267, 'noise_dx': 0.49716415275142134, 'noise_dy': 0.20290645220088652, 'qx': 4.501371009685251e-06, 'qy': 0.00013540941128899726, 'ff': 0.15784093825145212, 'cut_dist': 112.10787459042957}. Best is trial 29 with value: 0.10721264619243445.
# 100%|██████████| 102861/102861 [04:54<00:00, 348.78it/s]
# [I 2025-10-04 17:48:33,036] Trial 31 finished with value: 0.10330932034493151 and parameters: {'noise_x': 58.57660250830345, 'noise_y': 215.41949627746746, 'noise_dx': 0.43905361973814655, 'noise_dy': 0.3934371487645863, 'qx': 1.9163276763504753e-05, 'qy': 1.3351205710028699e-05, 'ff': 0.22502303538151838, 'cut_dist': 0.5153535841302246}. Best is trial 29 with value: 0.10721264619243445.
# 100%|██████████| 102861/102861 [05:24<00:00, 317.27it/s]
# [I 2025-10-04 17:54:08,343] Trial 32 finished with value: 0.10344542635206735 and parameters: {'noise_x': 111.23098861940407, 'noise_y': 221.3817233510757, 'noise_dx': 0.45386579386298237, 'noise_dy': 0.384190284232928, 'qx': 4.84711236108993e-08, 'qy': 2.9099826862878923e-06, 'ff': 0.2207572410453912, 'cut_dist': 1.1053231664045784}. Best is trial 29 with value: 0.10721264619243445.
# 100%|██████████| 102861/102861 [02:25<00:00, 706.93it/s]
# [I 2025-10-04 17:56:39,880] Trial 33 finished with value: 0.08778837460261907 and parameters: {'noise_x': 232.84301828886953, 'noise_y': 691.362069262254, 'noise_dx': 0.8573693572069734, 'noise_dy': 0.6136241957496966, 'qx': 3.335277203668806e-08, 'qy': 2.3123759643820167e-06, 'ff': 0.00906281357797159, 'cut_dist': 13.952513077311869}. Best is trial 29 with value: 0.10721264619243445.
# 100%|██████████| 102861/102861 [03:39<00:00, 468.13it/s]
# [I 2025-10-04 18:00:27,098] Trial 34 finished with value: 0.09273193921894596 and parameters: {'noise_x': 147.55595725392087, 'noise_y': 71.18380530806664, 'noise_dx': 4.541900904555875, 'noise_dy': 0.16083684243778182, 'qx': 1.9396657094118924e-07, 'qy': 2.0219689571088755e-05, 'ff': 0.25429187961271243, 'cut_dist': 2.424951294754022}. Best is trial 29 with value: 0.10721264619243445.
# 100%|██████████| 102861/102861 [06:11<00:00, 276.81it/s]
# [I 2025-10-04 18:06:51,565] Trial 35 finished with value: 0.1040676252418312 and parameters: {'noise_x': 76.89343403369278, 'noise_y': 228.84495405121498, 'noise_dx': 0.9034198639759256, 'noise_dy': 2.0985768667183624, 'qx': 6.411023851027466e-07, 'qy': 6.176669928944486e-08, 'ff': 0.390084018238621, 'cut_dist': 0.04066402446099064}. Best is trial 29 with value: 0.10721264619243445.
# 100%|██████████| 102861/102861 [05:52<00:00, 291.76it/s]
# [I 2025-10-04 18:12:56,394] Trial 36 finished with value: 0.10136494881441946 and parameters: {'noise_x': 36.38989766961426, 'noise_y': 67.2998919305168, 'noise_dx': 1.4692899741172123, 'noise_dy': 2.3592082053392724, 'qx': 1.1370524916889296e-06, 'qy': 5.0913441672860566e-08, 'ff': 0.4037034376949603, 'cut_dist': 0.06085529617413513}. Best is trial 29 with value: 0.10721264619243445.
# 100%|██████████| 102861/102861 [05:04<00:00, 338.00it/s]
# [I 2025-10-04 18:18:13,222] Trial 37 finished with value: 0.10398985038061073 and parameters: {'noise_x': 305.6285386697878, 'noise_y': 477.7853341611329, 'noise_dx': 3.420889238538083, 'noise_dy': 1.7731090372915828, 'qx': 4.964963946678619e-06, 'qy': 1.8040217787469213e-07, 'ff': 0.35950270837509646, 'cut_dist': 0.04092490568076542}. Best is trial 29 with value: 0.10721264619243445.
# 100%|██████████| 102861/102861 [05:07<00:00, 334.77it/s]
# [I 2025-10-04 18:23:34,946] Trial 38 finished with value: 0.09431660201631328 and parameters: {'noise_x': 8.96142553517952, 'noise_y': 140.58332371522408, 'noise_dx': 0.9354860520706798, 'noise_dy': 4.174550982588948, 'qx': 5.083023238002945e-07, 'qy': 0.00024333988487039825, 'ff': 0.14185496076522813, 'cut_dist': 0.00813080152016588}. Best is trial 29 with value: 0.10721264619243445.
# 100%|██████████| 102861/102861 [06:20<00:00, 270.48it/s]
# [I 2025-10-04 18:30:13,105] Trial 39 finished with value: 0.06620098968510903 and parameters: {'noise_x': 0.9759709224205562, 'noise_y': 8.7853621652979, 'noise_dx': 2.7001520098373626, 'noise_dy': 0.1088390635868014, 'qx': 4.113001931727212e-05, 'qy': 4.4100912396308376e-08, 'ff': 0.28910039174799773, 'cut_dist': 0.0008272038075407789}. Best is trial 29 with value: 0.10721264619243445.
# 100%|██████████| 102861/102861 [05:11<00:00, 330.08it/s]
# [I 2025-10-04 18:35:33,339] Trial 40 finished with value: 0.09040841523998405 and parameters: {'noise_x': 22.5058824586556, 'noise_y': 50.010829787125964, 'noise_dx': 7.478507089408239, 'noise_dy': 1.0211404620197932, 'qx': 1.5597944784813748e-07, 'qy': 1.0450144140617517e-08, 'ff': 0.42359145925117075, 'cut_dist': 0.34145533657713895}. Best is trial 29 with value: 0.10721264619243445.
# 100%|██████████| 102861/102861 [05:38<00:00, 304.19it/s]
# [I 2025-10-04 18:41:23,310] Trial 41 finished with value: 0.10313918783601171 and parameters: {'noise_x': 342.3423597546988, 'noise_y': 466.8714570037341, 'noise_dx': 3.6449317336196945, 'noise_dy': 1.8024359765058986, 'qx': 4.927686134661404e-06, 'qy': 3.7358993020499437e-07, 'ff': 0.39403114035208076, 'cut_dist': 0.061127834773870814}. Best is trial 29 with value: 0.10721264619243445.
# 100%|██████████| 102861/102861 [06:18<00:00, 271.75it/s]
# [I 2025-10-04 18:47:54,557] Trial 42 finished with value: 0.1017927105511321 and parameters: {'noise_x': 353.61159151850285, 'noise_y': 413.3011243998211, 'noise_dx': 0.3022458787516247, 'noise_dy': 3.830539263446879, 'qx': 1.003594810009211e-05, 'qy': 1.5201612542551063e-07, 'ff': 0.30940262427236115, 'cut_dist': 0.062475595375446336}. Best is trial 29 with value: 0.10721264619243445.
# 100%|██████████| 102861/102861 [05:19<00:00, 322.11it/s]
# [I 2025-10-04 18:53:27,047] Trial 43 finished with value: 0.10550646017441012 and parameters: {'noise_x': 76.71668591814908, 'noise_y': 206.20037487684175, 'noise_dx': 0.8307043325439699, 'noise_dy': 0.5391549753209909, 'qx': 2.0700547105713374e-06, 'qy': 1.1008903177445066e-07, 'ff': 0.549914442001042, 'cut_dist': 0.03057104125369459}. Best is trial 29 with value: 0.10721264619243445.
# 100%|██████████| 102861/102861 [05:55<00:00, 288.97it/s]
# [I 2025-10-04 18:59:37,724] Trial 44 finished with value: 0.0945304828846696 and parameters: {'noise_x': 61.8201605158663, 'noise_y': 156.15068353838265, 'noise_dx': 0.7387083433378222, 'noise_dy': 0.5634343422930347, 'qx': 1.3547560162132357e-06, 'qy': 5.213148912666055e-08, 'ff': 0.5382051823406573, 'cut_dist': 0.00558364599453268}. Best is trial 29 with value: 0.10721264619243445.
# 100%|██████████| 102861/102861 [06:20<00:00, 270.68it/s]
# [I 2025-10-04 19:06:15,576] Trial 45 finished with value: 0.0672363675251067 and parameters: {'noise_x': 89.87491411195846, 'noise_y': 858.2412779472285, 'noise_dx': 1.60742562745355, 'noise_dy': 0.07810443816056671, 'qx': 3.729670457076092e-07, 'qy': 4.964234004634779e-06, 'ff': 0.15609303146267295, 'cut_dist': 0.0014790706506658054}. Best is trial 29 with value: 0.10721264619243445.
# 100%|██████████| 102861/102861 [05:55<00:00, 289.07it/s]
# [I 2025-10-04 19:12:25,879] Trial 46 finished with value: 0.09252291927941592 and parameters: {'noise_x': 8.33842074329823, 'noise_y': 45.38966746141547, 'noise_dx': 0.2950289823154472, 'noise_dy': 0.29545791699094054, 'qx': 4.8510758463187094e-05, 'qy': 1.6495443865657252e-06, 'ff': 0.448099331246664, 'cut_dist': 0.017710804405448814}. Best is trial 29 with value: 0.10721264619243445.
# 100%|██████████| 102861/102861 [04:36<00:00, 372.11it/s]
# [I 2025-10-04 19:17:13,930] Trial 47 finished with value: 0.10285725396408746 and parameters: {'noise_x': 170.19760106685396, 'noise_y': 244.77696855136261, 'noise_dx': 0.6258260768085174, 'noise_dy': 0.5288894987062266, 'qx': 8.346698020450445e-08, 'qy': 2.401438071549951e-05, 'ff': 0.6091770194513706, 'cut_dist': 0.12156233097438625}. Best is trial 29 with value: 0.10721264619243445.
# 100%|██████████| 102861/102861 [04:04<00:00, 420.56it/s]
# [I 2025-10-04 19:21:28,718] Trial 48 finished with value: 0.09142921029350289 and parameters: {'noise_x': 516.1127331932432, 'noise_y': 11.526641703972299, 'noise_dx': 1.1464101915273892, 'noise_dy': 0.12023689299005456, 'qx': 2.2487995665784587e-08, 'qy': 2.9386116694129392e-08, 'ff': 0.5105330429461634, 'cut_dist': 0.8116944059467966}. Best is trial 29 with value: 0.10721264619243445.
# 100%|██████████| 102861/102861 [03:10<00:00, 539.09it/s]
# [I 2025-10-04 19:24:46,961] Trial 49 finished with value: 0.09798174235132849 and parameters: {'noise_x': 4.936676645997484, 'noise_y': 93.17746273423823, 'noise_dx': 2.334155024457444, 'noise_dy': 0.044626346022418814, 'qx': 2.2584443596013323e-06, 'qy': 7.628910309942003e-05, 'ff': 0.7719916129411715, 'cut_dist': 0.24487167233435755}. Best is trial 29 with value: 0.10721264619243445.
# 100%|██████████| 102861/102861 [05:57<00:00, 287.62it/s]
# [I 2025-10-04 19:31:00,420] Trial 50 finished with value: 0.0825969026161519 and parameters: {'noise_x': 72.84103637446276, 'noise_y': 42.17821509676301, 'noise_dx': 0.09062496296532875, 'noise_dy': 1.305925683462707, 'qx': 5.63296665575517e-07, 'qy': 7.190739063705544e-06, 'ff': 0.35268719979741237, 'cut_dist': 0.010876846554066106}. Best is trial 29 with value: 0.10721264619243445.
# 100%|██████████| 102861/102861 [05:18<00:00, 322.45it/s]
# [I 2025-10-04 19:36:32,507] Trial 51 finished with value: 0.10166632640164883 and parameters: {'noise_x': 317.07580133628505, 'noise_y': 509.2733164033518, 'noise_dx': 0.3108547361011373, 'noise_dy': 4.727588769494233, 'qx': 7.18943455698508e-06, 'qy': 3.139836794803868e-07, 'ff': 0.3521871079187646, 'cut_dist': 0.04153549219425259}. Best is trial 29 with value: 0.10721264619243445.
# 100%|██████████| 102861/102861 [04:57<00:00, 346.18it/s]
# [I 2025-10-04 19:41:43,085] Trial 52 finished with value: 0.10478218177929438 and parameters: {'noise_x': 203.95502192511498, 'noise_y': 294.9547207634469, 'noise_dx': 2.7483502577980583, 'noise_dy': 1.425756470931983, 'qx': 2.7672622655335164e-06, 'qy': 1.036618002976931e-07, 'ff': 0.19394849189526053, 'cut_dist': 0.029675954920691867}. Best is trial 29 with value: 0.10721264619243445.
# 100%|██████████| 102861/102861 [05:56<00:00, 288.13it/s]
# [I 2025-10-04 19:47:55,996] Trial 53 finished with value: 0.07988450433108758 and parameters: {'noise_x': 19.300732148954964, 'noise_y': 275.22885434548726, 'noise_dx': 9.615830107223399, 'noise_dy': 0.8738749461213666, 'qx': 1.040332566814057e-06, 'qy': 1.0924120232367e-07, 'ff': 0.18156868735876094, 'cut_dist': 0.0025229566182234523}. Best is trial 29 with value: 0.10721264619243445.
# 100%|██████████| 102861/102861 [05:18<00:00, 323.25it/s]
# [I 2025-10-04 19:53:28,118] Trial 54 finished with value: 0.09996500131245079 and parameters: {'noise_x': 186.4624418214121, 'noise_y': 140.54440359364793, 'noise_dx': 1.1798807813500836, 'noise_dy': 0.16462289316656512, 'qx': 2.306299510118383e-06, 'qy': 2.0999751752076854e-08, 'ff': 0.09685398185291103, 'cut_dist': 0.1357847267201374}. Best is trial 29 with value: 0.10721264619243445.
# 100%|██████████| 102861/102861 [05:41<00:00, 301.27it/s]
# [I 2025-10-04 19:59:25,765] Trial 55 finished with value: 0.07105219665373659 and parameters: {'noise_x': 37.76131165032649, 'noise_y': 96.98652883217434, 'noise_dx': 1.6645559514084138, 'noise_dy': 0.006944584061131421, 'qx': 1.0810458032267441e-07, 'qy': 8.881141398890638e-08, 'ff': 0.26769727929984194, 'cut_dist': 0.029837658670805157}. Best is trial 29 with value: 0.10721264619243445.
# 100%|██████████| 102861/102861 [03:19<00:00, 515.21it/s]
# [I 2025-10-04 20:02:51,696] Trial 56 finished with value: 0.08980079913669904 and parameters: {'noise_x': 621.0399158549832, 'noise_y': 961.8984843097683, 'noise_dx': 0.6271733438355039, 'noise_dy': 6.901453745092283, 'qx': 3.3454423989296056e-07, 'qy': 8.167792190477212e-07, 'ff': 0.04607406937881184, 'cut_dist': 3.7560587932866545}. Best is trial 29 with value: 0.10721264619243445.
# 100%|██████████| 102861/102861 [06:30<00:00, 263.19it/s]
# [I 2025-10-04 20:09:39,399] Trial 57 finished with value: 0.07265144223758276 and parameters: {'noise_x': 99.54335800142161, 'noise_y': 1.866107233565957, 'noise_dx': 5.729071815874419, 'noise_dy': 2.884425235046522, 'qx': 1.2878375428774209e-05, 'qy': 0.0004260288805374633, 'ff': 0.2091759532605761, 'cut_dist': 0.0004159665412915379}. Best is trial 29 with value: 0.10721264619243445.
# 100%|██████████| 102861/102861 [05:16<00:00, 324.50it/s]
# [I 2025-10-04 20:15:10,057] Trial 58 finished with value: 0.09889559697066916 and parameters: {'noise_x': 11.74170860838644, 'noise_y': 310.64907914261096, 'noise_dx': 2.355852213391418, 'noise_dy': 1.497010167898585, 'qx': 6.450737524844889e-05, 'qy': 2.747477456746734e-07, 'ff': 0.6308262211085922, 'cut_dist': 0.004254913599799182}. Best is trial 29 with value: 0.10721264619243445.
# 100%|██████████| 102861/102861 [07:33<00:00, 226.86it/s]
# [I 2025-10-04 20:23:00,662] Trial 59 finished with value: 0.07461039655457365 and parameters: {'noise_x': 1.7917967613817647, 'noise_y': 14.754374270670056, 'noise_dx': 0.0984170201443911, 'noise_dy': 0.33850645614174196, 'qx': 6.832654630287028e-07, 'qy': 6.591870202005006e-08, 'ff': 0.10690806419088701, 'cut_dist': 0.012478143626570442}. Best is trial 29 with value: 0.10721264619243445.
# 100%|██████████| 102861/102861 [06:36<00:00, 259.68it/s]
# [I 2025-10-04 20:29:52,800] Trial 60 finished with value: 0.07798874208883834 and parameters: {'noise_x': 951.0162596497171, 'noise_y': 0.0024850453077550293, 'noise_dx': 0.26452229844228986, 'noise_dy': 0.7452926528582308, 'qx': 0.0023559400084367985, 'qy': 4.994113449568268e-07, 'ff': 0.254024560964113, 'cut_dist': 0.001492033972236183}. Best is trial 29 with value: 0.10721264619243445.
# 100%|██████████| 102861/102861 [04:42<00:00, 363.66it/s]
# [I 2025-10-04 20:34:48,210] Trial 61 finished with value: 0.10260934659394717 and parameters: {'noise_x': 402.04785810952865, 'noise_y': 645.4102509514199, 'noise_dx': 4.530934619586928, 'noise_dy': 1.1782297316499135, 'qx': 5.5213352922401886e-06, 'qy': 1.6345595108416433e-07, 'ff': 0.3324989914382459, 'cut_dist': 0.04034748246490909}. Best is trial 29 with value: 0.10721264619243445.
# 100%|██████████| 102861/102861 [04:49<00:00, 355.55it/s]
# [I 2025-10-04 20:39:48,556] Trial 62 finished with value: 0.10094690893535938 and parameters: {'noise_x': 231.80259480956664, 'noise_y': 349.193072425237, 'noise_dx': 3.380924620007714, 'noise_dy': 1.9361202240859339, 'qx': 3.6746334481385777e-06, 'qy': 1.9960824073228586e-07, 'ff': 0.48710212925024443, 'cut_dist': 0.08166095591324934}. Best is trial 29 with value: 0.10721264619243445.
# 100%|██████████| 102861/102861 [05:42<00:00, 300.70it/s]
# [I 2025-10-04 20:45:43,744] Trial 63 finished with value: 0.09831228551151554 and parameters: {'noise_x': 33.13663748738502, 'noise_y': 134.08576305635734, 'noise_dx': 1.2501524167788591, 'noise_dy': 2.975059977762427, 'qx': 8.48705583734668e-06, 'qy': 3.14656813121884e-08, 'ff': 0.37849769529721966, 'cut_dist': 0.022496185049025907}. Best is trial 29 with value: 0.10721264619243445.
# 100%|██████████| 102861/102861 [05:06<00:00, 336.05it/s]
# [I 2025-10-04 20:51:07,532] Trial 64 finished with value: 0.10120453816315221 and parameters: {'noise_x': 0.012724390485888396, 'noise_y': 197.3611563023209, 'noise_dx': 2.0627002252881614, 'noise_dy': 0.206835777526118, 'qx': 1.6696766882433712e-06, 'qy': 1.5220270943857604e-06, 'ff': 0.19928102921626084, 'cut_dist': 0.20926052874570286}. Best is trial 29 with value: 0.10721264619243445.
# 100%|██████████| 102861/102861 [02:22<00:00, 721.03it/s]
# [I 2025-10-04 20:53:34,432] Trial 65 finished with value: 0.0894945606206434 and parameters: {'noise_x': 141.5663611323601, 'noise_y': 551.0157270743971, 'noise_dx': 0.9272636754287169, 'noise_dy': 0.46181984196435355, 'qx': 3.0078039482556556e-05, 'qy': 0.07955801653915379, 'ff': 0.5788287581932116, 'cut_dist': 0.4195661614570018}. Best is trial 29 with value: 0.10721264619243445.
# 100%|██████████| 102861/102861 [03:47<00:00, 452.72it/s]
# [I 2025-10-04 20:57:29,630] Trial 66 finished with value: 0.09065146168129806 and parameters: {'noise_x': 229.48628804602302, 'noise_y': 34.60306633957885, 'noise_dx': 3.258738896544582, 'noise_dy': 0.7536097050544164, 'qx': 8.595805877104508e-05, 'qy': 3.030001841660278e-05, 'ff': 0.28566783678478314, 'cut_dist': 0.9830122315745837}. Best is trial 29 with value: 0.10721264619243445.
# 100%|██████████| 102861/102861 [05:03<00:00, 339.15it/s]
# [I 2025-10-04 21:02:46,645] Trial 67 finished with value: 0.094433264308144 and parameters: {'noise_x': 83.62489505673172, 'noise_y': 61.77214576496902, 'noise_dx': 0.5616884107644289, 'noise_dy': 0.2373572135288686, 'qx': 0.00024356421051815875, 'qy': 9.327083329256671e-07, 'ff': 0.4328433991149395, 'cut_dist': 0.029929055862573065}. Best is trial 29 with value: 0.10721264619243445.
# 100%|██████████| 102861/102861 [06:48<00:00, 251.84it/s]
# [I 2025-10-04 21:09:50,627] Trial 68 finished with value: 0.0822274720253546 and parameters: {'noise_x': 54.241171202389545, 'noise_y': 93.2022987953597, 'noise_dx': 0.3778299520557342, 'noise_dy': 1.466654442028106, 'qx': 2.8230474616807142e-06, 'qy': 1.8980913165122186e-08, 'ff': 0.33067288518280136, 'cut_dist': 0.006516000078519045}. Best is trial 29 with value: 0.10721264619243445.
# 100%|██████████| 102861/102861 [05:37<00:00, 305.02it/s]
# [I 2025-10-04 21:15:40,788] Trial 69 finished with value: 0.1073730568437017 and parameters: {'noise_x': 452.09554938937777, 'noise_y': 370.74147106648815, 'noise_dx': 0.05778018834994987, 'noise_dy': 0.012844430861403851, 'qx': 1.5752356577275266e-05, 'qy': 0.00016076994193566904, 'ff': 0.24583925851264898, 'cut_dist': 0.17200846898508562}. Best is trial 69 with value: 0.1073730568437017.
# 100%|██████████| 102861/102861 [04:03<00:00, 422.20it/s]
# [I 2025-10-04 21:19:51,273] Trial 70 finished with value: 0.10195798213122563 and parameters: {'noise_x': 753.9621878969924, 'noise_y': 182.96545299285208, 'noise_dx': 0.044981581460263056, 'noise_dy': 0.012229859893382213, 'qx': 2.2339255121768388e-05, 'qy': 0.00016650833191258848, 'ff': 0.12908967015912381, 'cut_dist': 9.983232095462409}. Best is trial 69 with value: 0.1073730568437017.
# 100%|██████████| 102861/102861 [05:28<00:00, 313.36it/s]
# [I 2025-10-04 21:25:30,775] Trial 71 finished with value: 0.09581376809480756 and parameters: {'noise_x': 378.81480069545233, 'noise_y': 400.1269024763784, 'noise_dx': 0.016825210421710007, 'noise_dy': 0.004932437375708263, 'qx': 1.4420815759121246e-05, 'qy': 0.0026359714691446545, 'ff': 0.23085863699449372, 'cut_dist': 0.188419428420679}. Best is trial 69 with value: 0.1073730568437017.
# 100%|██████████| 102861/102861 [05:42<00:00, 299.93it/s]
# [I 2025-10-04 21:31:26,788] Trial 72 finished with value: 0.10068927970756653 and parameters: {'noise_x': 509.9362927705132, 'noise_y': 343.9017859806971, 'noise_dx': 0.12748958929924034, 'noise_dy': 0.03163335337405924, 'qx': 2.49521232181266e-07, 'qy': 0.0011302634635584573, 'ff': 0.18391085668531765, 'cut_dist': 0.08807866768833478}. Best is trial 69 with value: 0.1073730568437017.
# 100%|██████████| 102861/102861 [03:42<00:00, 462.59it/s]
# [I 2025-10-04 21:35:17,040] Trial 73 finished with value: 0.0872196459299443 and parameters: {'noise_x': 0.4539749311405304, 'noise_y': 641.4221437838124, 'noise_dx': 0.058267190581050586, 'noise_dy': 0.008279898547746557, 'qx': 0.0633453581602737, 'qy': 0.0005031947133233315, 'ff': 0.37470191951511, 'cut_dist': 0.042783648059057}. Best is trial 69 with value: 0.1073730568437017.
# 100%|██████████| 102861/102861 [06:50<00:00, 250.66it/s]
# [I 2025-10-04 21:42:22,534] Trial 74 finished with value: 0.08432253234948134 and parameters: {'noise_x': 117.74571127459397, 'noise_y': 234.69611870108534, 'noise_dx': 0.21002852456776816, 'noise_dy': 0.022704227600725758, 'qx': 6.5792491893647934e-06, 'qy': 8.599026264312976e-05, 'ff': 0.3129896798753353, 'cut_dist': 0.013078620169903937}. Best is trial 69 with value: 0.1073730568437017.
# 100%|██████████| 102861/102861 [03:46<00:00, 454.43it/s]
# [I 2025-10-04 21:46:17,157] Trial 75 finished with value: 0.10248782337329017 and parameters: {'noise_x': 267.38156692286935, 'noise_y': 60.45432122136862, 'noise_dx': 0.7701900114373182, 'noise_dy': 0.04941545593488612, 'qx': 1.0648643337669765e-06, 'qy': 0.0002897748879759698, 'ff': 0.248787759035732, 'cut_dist': 1.4764277825724972}. Best is trial 69 with value: 0.1073730568437017.
# 100%|██████████| 102861/102861 [05:52<00:00, 291.41it/s]
# [I 2025-10-04 21:52:23,499] Trial 76 finished with value: 0.10221561135901848 and parameters: {'noise_x': 169.8221176583263, 'noise_y': 105.51573946096204, 'noise_dx': 0.07975970806911457, 'noise_dy': 0.015398042929185575, 'qx': 3.63004238647556e-06, 'qy': 4.9104218237075636e-06, 'ff': 0.18248048911008813, 'cut_dist': 0.6001541977156581}. Best is trial 69 with value: 0.1073730568437017.
# 100%|██████████| 102861/102861 [05:02<00:00, 340.29it/s]
# [I 2025-10-04 21:57:36,646] Trial 77 finished with value: 0.08718075849933406 and parameters: {'noise_x': 970.2635103567408, 'noise_y': 0.03431142201304185, 'noise_dx': 1.4870621758167608, 'noise_dy': 0.0901165102772135, 'qx': 2.977257597712812e-05, 'qy': 8.606275605686472e-08, 'ff': 0.6585239074767912, 'cut_dist': 0.2630713110163018}. Best is trial 69 with value: 0.1073730568437017.
# 100%|██████████| 102861/102861 [06:47<00:00, 252.31it/s]
# [I 2025-10-04 22:04:38,778] Trial 78 finished with value: 0.09805465628372269 and parameters: {'noise_x': 498.4283102987196, 'noise_y': 179.10546353215932, 'noise_dx': 6.597197748769684, 'noise_dy': 2.3628920617338673, 'qx': 1.702810025850637e-06, 'qy': 3.947802548636993e-05, 'ff': 0.2803681966812578, 'cut_dist': 0.0031123377095368015}. Best is trial 69 with value: 0.1073730568437017.
# 100%|██████████| 102861/102861 [05:10<00:00, 330.81it/s]
# [I 2025-10-04 22:10:01,145] Trial 79 finished with value: 0.10425720146605613 and parameters: {'noise_x': 26.780422900974646, 'noise_y': 804.1191321097532, 'noise_dx': 0.03233573292205723, 'noise_dy': 0.15178853143725227, 'qx': 6.830175932221666e-07, 'qy': 1.1015555351172945e-05, 'ff': 0.05763727562380208, 'cut_dist': 4.690676025370386}. Best is trial 69 with value: 0.1073730568437017.
# 100%|██████████| 102861/102861 [03:36<00:00, 475.12it/s]
# [I 2025-10-04 22:13:44,890] Trial 80 finished with value: 0.09446729080992797 and parameters: {'noise_x': 23.771346252318637, 'noise_y': 940.20345826244, 'noise_dx': 0.02905834976067297, 'noise_dy': 0.14829868497497495, 'qx': 8.424474557027868e-07, 'qy': 1.2952174585375219e-05, 'ff': 0.037030370559873016, 'cut_dist': 45.63687784259983}. Best is trial 69 with value: 0.1073730568437017.
# 100%|██████████| 102861/102861 [02:24<00:00, 711.61it/s]
# [I 2025-10-04 22:16:13,243] Trial 81 finished with value: 0.0766276820174799 and parameters: {'noise_x': 51.292433190417164, 'noise_y': 507.4791071744189, 'noise_dx': 0.04554750401485646, 'noise_dy': 0.18368086797079058, 'qx': 4.7014684963352036e-07, 'qy': 6.369630283520465e-05, 'ff': 0.08204867891115826, 'cut_dist': 287.00796526320016}. Best is trial 69 with value: 0.1073730568437017.
# 100%|██████████| 102861/102861 [05:23<00:00, 317.59it/s]
# [I 2025-10-04 22:21:48,676] Trial 82 finished with value: 0.09875463003470702 and parameters: {'noise_x': 92.95394948807984, 'noise_y': 294.8900046311076, 'noise_dx': 0.017247215830924045, 'noise_dy': 0.3068706789495509, 'qx': 1.0928376865317864e-07, 'qy': 1.440963519017261e-05, 'ff': 0.12579255401076544, 'cut_dist': 4.289032876829766}. Best is trial 69 with value: 0.1073730568437017.
# 100%|██████████| 102861/102861 [05:44<00:00, 298.40it/s]
# [I 2025-10-04 22:27:47,410] Trial 83 finished with value: 0.09555127793818843 and parameters: {'noise_x': 204.33698008448476, 'noise_y': 661.926877157413, 'noise_dx': 0.011348153922056837, 'noise_dy': 1.0095422583266003, 'qx': 1.0670739234119608e-05, 'qy': 0.00012758843186299023, 'ff': 0.01737359932116142, 'cut_dist': 0.08866469616979919}. Best is trial 69 with value: 0.1073730568437017.
# 100%|██████████| 102861/102861 [07:22<00:00, 232.64it/s]
# [I 2025-10-04 22:35:25,712] Trial 84 finished with value: 0.07582562876114368 and parameters: {'noise_x': 32.78894162709745, 'noise_y': 424.1367006958332, 'noise_dx': 0.11723394837432145, 'noise_dy': 0.4351606576428054, 'qx': 4.217694024069787e-06, 'qy': 5.510323145361105e-07, 'ff': 0.1585818161038197, 'cut_dist': 0.01735008355087237}. Best is trial 69 with value: 0.1073730568437017.
# 100%|██████████| 102861/102861 [06:25<00:00, 266.56it/s]
# [I 2025-10-04 22:42:08,739] Trial 85 finished with value: 0.0720049387036875 and parameters: {'noise_x': 76.03021750695824, 'noise_y': 121.41762998973188, 'noise_dx': 0.37882668532159913, 'noise_dy': 0.13379589380518628, 'qx': 2.409756247654806e-07, 'qy': 4.8148356898803605e-06, 'ff': 0.07103022028533612, 'cut_dist': 0.008574509741083588}. Best is trial 69 with value: 0.1073730568437017.
# 100%|██████████| 102861/102861 [06:26<00:00, 265.89it/s]
# [I 2025-10-04 22:48:49,879] Trial 86 finished with value: 0.1032607110566687 and parameters: {'noise_x': 17.253491604440704, 'noise_y': 223.0192713501193, 'noise_dx': 0.23089348032543708, 'noise_dy': 0.24872096805001, 'qx': 2.0004140252561473e-06, 'qy': 1.635556458616065e-06, 'ff': 0.23564269740491872, 'cut_dist': 0.05480901178723343}. Best is trial 69 with value: 0.1073730568437017.
# 100%|██████████| 102861/102861 [05:33<00:00, 308.83it/s]
# [I 2025-10-04 22:54:33,759] Trial 87 finished with value: 0.10308085669009634 and parameters: {'noise_x': 131.24659147098407, 'noise_y': 71.71186584708283, 'noise_dx': 0.07207729517189652, 'noise_dy': 0.0781278983588248, 'qx': 7.038366426050035e-07, 'qy': 0.0002136897779565347, 'ff': 0.7286284434558877, 'cut_dist': 0.156360051543417}. Best is trial 69 with value: 0.1073730568437017.
# 100%|██████████| 102861/102861 [04:23<00:00, 390.13it/s]
# [I 2025-10-04 22:59:05,080] Trial 88 finished with value: 0.08428850584769738 and parameters: {'noise_x': 47.0124768849613, 'noise_y': 5.380771468498619, 'noise_dx': 2.6623061219129966, 'noise_dy': 0.016220970163419175, 'qx': 2.3718549478751797e-08, 'qy': 2.024137737306886e-07, 'ff': 0.46339908200942026, 'cut_dist': 5.55258206836353}. Best is trial 69 with value: 0.1073730568437017.
# 100%|██████████| 102861/102861 [06:05<00:00, 281.09it/s]
# [I 2025-10-04 23:05:24,400] Trial 89 finished with value: 0.10223019414549732 and parameters: {'noise_x': 277.56210057147837, 'noise_y': 18.181724586735076, 'noise_dx': 0.05132918130969166, 'noise_dy': 0.625545520358019, 'qx': 6.8007515820787e-08, 'qy': 3.4951125999899944e-08, 'ff': 0.16084757887002327, 'cut_dist': 0.387689339139557}. Best is trial 69 with value: 0.1073730568437017.
# 100%|██████████| 102861/102861 [07:21<00:00, 232.97it/s]
# [I 2025-10-04 23:13:04,839] Trial 90 finished with value: 0.06535032714051 and parameters: {'noise_x': 443.8612245717165, 'noise_y': 0.05558204633039569, 'noise_dx': 0.03721366866749208, 'noise_dy': 0.03229377932498968, 'qx': 1.4620168723071243e-06, 'qy': 9.041278372661545e-06, 'ff': 0.9453435199433294, 'cut_dist': 1.0075664217435882e-06}. Best is trial 69 with value: 0.1073730568437017.
# 100%|██████████| 102861/102861 [03:50<00:00, 445.33it/s]
# [I 2025-10-04 23:17:04,026] Trial 91 finished with value: 0.09557072165349355 and parameters: {'noise_x': 119.38319197973641, 'noise_y': 317.879947077483, 'noise_dx': 0.5353024956576213, 'noise_dy': 5.412880345686268, 'qx': 4.2347382626022965e-08, 'qy': 2.6499476316569663e-06, 'ff': 0.21819473793876873, 'cut_dist': 1.168528055063898}. Best is trial 69 with value: 0.1073730568437017.
# 100%|██████████| 102861/102861 [03:33<00:00, 482.71it/s]
# [I 2025-10-04 23:20:41,489] Trial 92 finished with value: 0.08296147227812291 and parameters: {'noise_x': 182.36600194985002, 'noise_y': 176.52686812971848, 'noise_dx': 1.0137610130744308, 'noise_dy': 0.379201771596146, 'qx': 1.1478985894572818e-07, 'qy': 1.8052816373927158e-05, 'ff': 0.19823771860253986, 'cut_dist': 25.42916528498053}. Best is trial 69 with value: 0.1073730568437017.
# 100%|██████████| 102861/102861 [03:55<00:00, 436.01it/s]
# [I 2025-10-04 23:24:44,606] Trial 93 finished with value: 0.09448673452523308 and parameters: {'noise_x': 65.13464856655891, 'noise_y': 699.4487322518672, 'noise_dx': 0.4136828260681308, 'noise_dy': 3.1844739355512703, 'qx': 7.3535081602818535e-06, 'qy': 3.7759450236442295e-05, 'ff': 0.30839234483847794, 'cut_dist': 1.9386360929840005}. Best is trial 69 with value: 0.1073730568437017.
# 100%|██████████| 102861/102861 [04:38<00:00, 369.18it/s]
# [I 2025-10-04 23:29:32,980] Trial 94 finished with value: 0.09280971408016644 and parameters: {'noise_x': 653.1331768916269, 'noise_y': 0.8079732524623785, 'noise_dx': 0.6655711167271265, 'noise_dy': 1.6467828402719928, 'qx': 3.288582668340195e-07, 'qy': 4.070608197999727e-07, 'ff': 0.2746956839244809, 'cut_dist': 0.7764586713959384}. Best is trial 69 with value: 0.1073730568437017.
# 100%|██████████| 102861/102861 [02:47<00:00, 612.67it/s]
# [I 2025-10-04 23:32:24,429] Trial 95 finished with value: 0.06418856515102905 and parameters: {'noise_x': 305.738172908182, 'noise_y': 268.27197698849585, 'noise_dx': 1.9323735546725953, 'noise_dy': 0.11078321231318448, 'qx': 1.4308896723248948e-08, 'qy': 1.3226113714768794e-07, 'ff': 0.8018865528359009, 'cut_dist': 7.467360595816863}. Best is trial 69 with value: 0.1073730568437017.
# 100%|██████████| 102861/102861 [05:28<00:00, 313.51it/s]
# [I 2025-10-04 23:38:06,281] Trial 96 finished with value: 0.10219616764371336 and parameters: {'noise_x': 29.63532841542093, 'noise_y': 437.5838651733154, 'noise_dx': 1.3190794689134595, 'noise_dy': 0.49770539108167294, 'qx': 2.8177922504499837e-06, 'qy': 3.826533149941749e-06, 'ff': 0.3439693627094823, 'cut_dist': 0.02608714489011741}. Best is trial 69 with value: 0.1073730568437017.
# 100%|██████████| 102861/102861 [04:28<00:00, 382.91it/s]
# [I 2025-10-04 23:42:46,066] Trial 97 finished with value: 0.09628041726213045 and parameters: {'noise_x': 6.825385261965166, 'noise_y': 143.226851234139, 'noise_dx': 0.021444933026345845, 'noise_dy': 0.8750734690677181, 'qx': 5.094726211124636e-08, 'qy': 0.00010857389754827223, 'ff': 0.11224198400491381, 'cut_dist': 2.4455087798725206}. Best is trial 69 with value: 0.1073730568437017.
# 100%|██████████| 102861/102861 [05:07<00:00, 334.37it/s]
# [I 2025-10-04 23:48:07,020] Trial 98 finished with value: 0.09835603387095206 and parameters: {'noise_x': 94.33280521158129, 'noise_y': 33.01077809986441, 'noise_dx': 1.039164158753517, 'noise_dy': 0.2951491541836464, 'qx': 1.7311458324923714e-07, 'qy': 7.35536231356916e-08, 'ff': 0.25653697802325365, 'cut_dist': 0.10531768369437405}. Best is trial 69 with value: 0.1073730568437017.
# 100%|██████████| 102861/102861 [03:00<00:00, 570.12it/s]
# [I 2025-10-04 23:51:13,159] Trial 99 finished with value: 0.07079456742594376 and parameters: {'noise_x': 0.001551495575431169, 'noise_y': 778.2668741169682, 'noise_dx': 0.16883697805075287, 'noise_dy': 0.2101097003326159, 'qx': 0.9853171880454614, 'qy': 6.965352793031193e-06, 'ff': 0.4135483290130311, 'cut_dist': 0.29611405145172925}. Best is trial 69 with value: 0.1073730568437017.
