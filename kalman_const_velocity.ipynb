# %%
import torch as pt
import pandas as pd
import numpy as np
import pyproj as pp
import tqdm
import gc
import optuna
import atd2025

# %%
# Read dataset in
data = pd.read_csv("https://www.maserv.work/ATD/model2/ucf_atd_model/datasets/dataset1_truth.csv")
data["time"] = pd.to_datetime(data["time"])

# %%
wgs84 = pp.CRS.from_epsg(4326)
utm = pp.CRS.from_epsg(32616)
to_utm = pp.Transformer.from_crs(wgs84, utm)

rad_earth = 6371000

x, y = to_utm.transform(data["lat"].to_numpy(), data["lon"].to_numpy())

x = x.astype("float32")
y = y.astype("float32")

# Read in rest of data
t = data["time"]
t = (t - t[0]).astype("timedelta64[s]").astype("int").astype("float32")
speed = data["speed"].to_numpy().astype("float32")
course = data["course"].to_numpy().astype("float32") * np.pi / 180

x = pt.tensor(x)
y = pt.tensor(y)
t = pt.tensor(t)
dx = pt.tensor(np.sin(course) * speed)
dy = pt.tensor(np.cos(course) * speed)

gc.collect()
# Out:
# 20

# %%
def objective(trial: optuna.Trial):
    max_size = data.shape[0]
    state_size = 4

    # Keeps all tracks we have previously found
    mus = pt.zeros((max_size, state_size, 1))
    covs = pt.zeros((max_size, state_size, state_size))
    last_times = pt.zeros((max_size))
    track_id = pt.zeros((max_size), dtype=pt.long)

    # Used to keep track of where we are when filtering
    idxs = pt.arange(max_size)

    noise_x = trial.suggest_float("noise_x", 1e-3, 500)
    noise_y = trial.suggest_float("noise_y", 1e-3, 500)
    noise_dx = trial.suggest_float("noise_dx", 1e-3, 5)
    noise_dy = trial.suggest_float("noise_dy", 1e-3, 5)
    
    # Noise propogation constants
    qx = trial.suggest_float("qx", 1e-5, 1)
    qy = trial.suggest_float("qy", 1e-5, 1)

    # Man dist cutoff
    cut_dist = trial.suggest_float("cut_dist", 1e-5, 1000)

    meas_noise = pt.diag(pt.tensor([noise_x, noise_dx, noise_y, noise_dy], dtype=pt.float32))
    # H = pt.zeros((state_size - 1, state_size))
    H = pt.eye(state_size)

    # Prior state covariance matrix
    prior_cov = (pt.eye(state_size) * 0.1)
    prior_cov[:state_size, :state_size] += meas_noise

    # Generate state transition matrix for CTRV
    def F_gen(dt, filter):
        F = pt.zeros((pt.sum(filter), state_size, state_size))
        
        # Set constants
        F[:, 0, 0] = 1
        F[:, 1, 1] = 1
        F[:, 2, 2] = 1
        F[:, 3, 3] = 1

        F[:, 0, 1] = dt
        F[:, 2, 3] = dt

        return F

    # Generate state noise matrix for CTRV
    def Q_gen(dt, filter):
        Q = pt.zeros((pt.sum(filter), state_size, state_size))
        dt3 = (dt ** 3) / 3
        dt2 = (dt ** 2) / 2
        
        Q[:, 0, 0] = qx * dt3
        Q[:, 0, 1] = qx * dt2
        Q[:, 1, 0] = qx * dt2
        Q[:, 1, 1] = qx * dt

        Q[:, 2, 2] = qy * dt3
        Q[:, 2, 3] = qy * dt2
        Q[:, 3, 2] = qy * dt2
        Q[:, 3, 3] = qy * dt

        return Q

    # Add new track to list
    def add_track(next_track_id, i):
        # Create state
        ti = t[i]
        xi = x[i]
        yi = y[i]
        dxi = dx[i]
        dyi = dy[i]

        # Update
        track_id[i] = next_track_id
        mus[next_track_id] = pt.tensor([xi, dxi, yi, dyi])[:, None]
        covs[next_track_id] = prior_cov
        last_times[next_track_id] = ti
        
    # Update an old track in the list
    def update_track(best_id, mu, cov, S, y_resid, time, i):
        # Calculate Kalman gain / intermediate value
        K = (pt.linalg.solve(S, H) @ cov).T
        imk = pt.eye(state_size) - (K @ H)
        
        # Calculate posterior mu/cov
        post_mu = mu + (K @ y_resid) 
        post_cov = (imk @ cov @ imk.T) + (K @ meas_noise @ K.T)

        # Update
        track_id[i] = best_id
        mus[best_id] = post_mu
        covs[best_id] = post_cov
        last_times[best_id] = time

    # Actual algorithm
    next_track_id = 0
    for i, time in tqdm.tqdm(enumerate(t), total=t.shape[0]):
        if next_track_id == 0:
            add_track(next_track_id, i)
            next_track_id += 1
            continue

        
        filter = (time - last_times[:next_track_id]) >= 2
        
        if not pt.any(filter):
            add_track(next_track_id, i)
            next_track_id += 1
            continue
        else:
            # Check best manhalobis distance, update if below threshold
            prev_times = last_times[:next_track_id][filter]
            dt = time - prev_times

            filtered_idxs = idxs[:next_track_id][filter]
            est_cov = covs[:next_track_id][filter]
            est_mu = mus[:next_track_id][filter]

            # Get F and Q
            F = F_gen(dt, filter)
            Q = Q_gen(dt, filter)

            # Get prior guess of state
            est_mu = F @ est_mu
            est_cov = (F @ est_cov @ F.mT) + Q

            # Get prior guess of measurement
            est_mu_y = H @ est_mu
            est_cov_y = (H @ est_cov @ H.T) + meas_noise

            # Get man dist between measurement and guess for measurement
            measurement = pt.tensor([x[i], dx[i], y[i], dy[i]])[:, None]
            measurement_resid = measurement - est_mu_y
            man_dist = (measurement_resid.mT @ pt.linalg.solve(est_cov_y, measurement_resid)).squeeze()

            best_man_dist_idx = pt.argmin(man_dist)
            best_man_dist = man_dist[best_man_dist_idx]
            best_track_id = track_id[filtered_idxs[best_man_dist_idx]]
            if best_man_dist <= cut_dist:
                # Update track
                mu = est_mu[best_man_dist_idx]
                cov = est_cov[best_man_dist_idx]
                S = est_cov_y[best_man_dist_idx]
                y_resid = measurement_resid[best_man_dist_idx]
                update_track(best_track_id, mu, cov, S, y_resid, time, i)
            else:
                # New track
                add_track(next_track_id, i)
                next_track_id += 1
                continue
    
    tids = track_id.numpy()
    pids = data["point_id"]

    pd.DataFrame({"point_id": pids, "track_id": tids}).to_csv("grademe.csv")
    gc.collect()
    return atd2025.accuracy.evaluate_predictions("grademe.csv", "https://www.maserv.work/ATD/model2/ucf_atd_model/datasets/dataset1_truth.csv")

# %%
study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=100)
# Out:
# [I 2025-10-03 21:38:28,401] A new study created in memory with name: no-name-fa90eadd-57a6-4237-886f-30ea72d8613a
# 100%|██████████| 102861/102861 [01:51<00:00, 918.41it/s]
# [I 2025-10-03 21:40:23,555] Trial 0 finished with value: 0.050087010625990414 and parameters: {'noise_x': 175.49884434381377, 'noise_y': 349.6329169813476, 'noise_dx': 2.265604663288929, 'noise_dy': 0.8637702035210998, 'qx': 0.06465484014658862, 'qy': 0.7536058878017058, 'cut_dist': 706.8559998949561}. Best is trial 0 with value: 0.050087010625990414.
# 100%|██████████| 102861/102861 [01:43<00:00, 997.42it/s]
# [I 2025-10-03 21:42:09,780] Trial 1 finished with value: 0.05563333041677604 and parameters: {'noise_x': 266.52238501798956, 'noise_y': 1.5744541675416657, 'noise_dx': 3.762546392129636, 'noise_dy': 3.2400046087281056, 'qx': 0.5031044985578316, 'qy': 0.27736575399047414, 'cut_dist': 600.9029684584173}. Best is trial 1 with value: 0.05563333041677604.
# 100%|██████████| 102861/102861 [01:37<00:00, 1057.80it/s]
# [I 2025-10-03 21:43:50,101] Trial 2 finished with value: 0.05999358357394931 and parameters: {'noise_x': 233.91338444988125, 'noise_y': 108.97046273623187, 'noise_dx': 0.7519001729064972, 'noise_dy': 0.4618495061179381, 'qx': 0.016432731651934155, 'qy': 0.8076317008028902, 'cut_dist': 195.51385290688316}. Best is trial 2 with value: 0.05999358357394931.
# 100%|██████████| 102861/102861 [00:51<00:00, 2001.61it/s]
# [I 2025-10-03 21:44:44,590] Trial 3 finished with value: 0.06245807448887333 and parameters: {'noise_x': 481.13555724828166, 'noise_y': 85.35739737725687, 'noise_dx': 2.2257653704901594, 'noise_dy': 2.041776421453366, 'qx': 0.523297485529553, 'qy': 0.4861569900979169, 'cut_dist': 124.17574100156314}. Best is trial 3 with value: 0.06245807448887333.
# 100%|██████████| 102861/102861 [01:53<00:00, 909.95it/s]
# [I 2025-10-03 21:46:40,748] Trial 4 finished with value: 0.04878428170054734 and parameters: {'noise_x': 289.50449840779606, 'noise_y': 431.09006621095784, 'noise_dx': 0.8091995905930452, 'noise_dy': 0.986641591000379, 'qx': 0.8233891213857962, 'qy': 0.1263895440373847, 'cut_dist': 495.18378606476915}. Best is trial 3 with value: 0.06245807448887333.
# 100%|██████████| 102861/102861 [01:50<00:00, 934.39it/s]
# [I 2025-10-03 21:48:33,860] Trial 5 finished with value: 0.046980877105997416 and parameters: {'noise_x': 477.5785580453352, 'noise_y': 208.47081484977437, 'noise_dx': 4.247547752356384, 'noise_dy': 3.413995631256432, 'qx': 0.7706660423881797, 'qy': 0.730838690671753, 'cut_dist': 705.2784157667475}. Best is trial 3 with value: 0.06245807448887333.
# 100%|██████████| 102861/102861 [01:42<00:00, 999.36it/s]
# [I 2025-10-03 21:50:20,011] Trial 6 finished with value: 0.057499927086067604 and parameters: {'noise_x': 440.9663573585658, 'noise_y': 50.30673926765359, 'noise_dx': 0.40832079675134453, 'noise_dy': 1.5628494772546067, 'qx': 0.8924603108718108, 'qy': 0.07883813521381557, 'cut_dist': 250.1802640905008}. Best is trial 3 with value: 0.06245807448887333.
# 100%|██████████| 102861/102861 [01:36<00:00, 1066.90it/s]
# [I 2025-10-03 21:51:59,466] Trial 7 finished with value: 0.046946850604213455 and parameters: {'noise_x': 423.8118657568372, 'noise_y': 51.67840325727004, 'noise_dx': 3.6277179756370184, 'noise_dy': 4.281978032375365, 'qx': 0.8893542601396183, 'qy': 0.8591409188811007, 'cut_dist': 956.6061174566137}. Best is trial 3 with value: 0.06245807448887333.
# 100%|██████████| 102861/102861 [01:56<00:00, 881.22it/s]
# [I 2025-10-03 21:53:59,307] Trial 8 finished with value: 0.05561388670147092 and parameters: {'noise_x': 290.976984298191, 'noise_y': 358.81114636377396, 'noise_dx': 3.0313054827425954, 'noise_dy': 3.761042903750397, 'qx': 0.4119682312847933, 'qy': 0.7457318290156079, 'cut_dist': 174.12604345332667}. Best is trial 3 with value: 0.06245807448887333.
# 100%|██████████| 102861/102861 [00:51<00:00, 1990.21it/s]
# [I 2025-10-03 21:54:54,155] Trial 9 finished with value: 0.063371929108214 and parameters: {'noise_x': 200.89441835019747, 'noise_y': 120.55082337656987, 'noise_dx': 4.259115332820499, 'noise_dy': 4.000742320416807, 'qx': 0.385029928753702, 'qy': 0.691408477418413, 'cut_dist': 83.85141660721088}. Best is trial 9 with value: 0.063371929108214.
# 100%|██████████| 102861/102861 [01:13<00:00, 1406.93it/s]
# [I 2025-10-03 21:56:10,364] Trial 10 finished with value: 0.058301980342403824 and parameters: {'noise_x': 7.950452810107663, 'noise_y': 199.01943793393963, 'noise_dx': 4.809682789918063, 'noise_dy': 4.908940822759832, 'qx': 0.2290325708767525, 'qy': 0.9913920890076324, 'cut_dist': 378.25732518156815}. Best is trial 9 with value: 0.063371929108214.
# 100%|██████████| 102861/102861 [01:57<00:00, 876.88it/s]
# [I 2025-10-03 21:58:10,949] Trial 11 finished with value: 0.07746862270442637 and parameters: {'noise_x': 120.72803783980483, 'noise_y': 142.23078939238212, 'noise_dx': 1.912259510055978, 'noise_dy': 2.286446975218715, 'qx': 0.536640174402456, 'qy': 0.4907562857189718, 'cut_dist': 6.6051409325072115}. Best is trial 11 with value: 0.07746862270442637.
# 100%|██████████| 102861/102861 [01:52<00:00, 917.21it/s]
# [I 2025-10-03 22:00:06,206] Trial 12 finished with value: 0.06999251416960753 and parameters: {'noise_x': 94.35411804763316, 'noise_y': 167.7531535452698, 'noise_dx': 1.5770026643994874, 'noise_dy': 2.6565883053847075, 'qx': 0.6339839334522888, 'qy': 0.5379909374946262, 'cut_dist': 40.21373691090727}. Best is trial 11 with value: 0.07746862270442637.
# 100%|██████████| 102861/102861 [01:49<00:00, 941.83it/s]
# [I 2025-10-03 22:01:58,620] Trial 13 finished with value: 0.06956475243289488 and parameters: {'noise_x': 70.5503216243745, 'noise_y': 272.4431030221039, 'noise_dx': 1.5629828777957504, 'noise_dy': 2.4117848456852364, 'qx': 0.6456962785094077, 'qy': 0.5035533996744203, 'cut_dist': 40.56202267682755}. Best is trial 11 with value: 0.07746862270442637.
# 100%|██████████| 102861/102861 [01:56<00:00, 886.05it/s]
# [I 2025-10-03 22:03:57,676] Trial 14 finished with value: 0.05478266787217702 and parameters: {'noise_x': 112.78759633141581, 'noise_y': 161.67677390403136, 'noise_dx': 1.4537109244141497, 'noise_dy': 2.9417334757123488, 'qx': 0.6664091563930028, 'qy': 0.5025842604539255, 'cut_dist': 368.4610558608929}. Best is trial 11 with value: 0.07746862270442637.
# 100%|██████████| 102861/102861 [01:26<00:00, 1187.66it/s]
# [I 2025-10-03 22:05:27,371] Trial 15 finished with value: 0.05185638871875638 and parameters: {'noise_x': 121.104019744857, 'noise_y': 268.65654683415596, 'noise_dx': 1.5359947590918261, 'noise_dy': 1.89327271910801, 'qx': 0.9999460166511593, 'qy': 0.3357580356672116, 'cut_dist': 307.81518401673577}. Best is trial 11 with value: 0.07746862270442637.
# 100%|██████████| 102861/102861 [01:51<00:00, 926.29it/s]
# [I 2025-10-03 22:07:21,591] Trial 16 finished with value: 0.08198928651286688 and parameters: {'noise_x': 20.22354137358178, 'noise_y': 154.31883595638595, 'noise_dx': 2.8104998875569565, 'noise_dy': 2.7109655544871076, 'qx': 0.6213902511947982, 'qy': 0.5828301525092747, 'cut_dist': 2.1070194571257854}. Best is trial 16 with value: 0.08198928651286688.
# 100%|██████████| 102861/102861 [01:59<00:00, 858.00it/s]
# [I 2025-10-03 22:09:24,641] Trial 17 finished with value: 0.08020046470479579 and parameters: {'noise_x': 15.33461932324073, 'noise_y': 318.3084219138513, 'noise_dx': 2.8939324355261355, 'noise_dy': 1.6115929357436845, 'qx': 0.30005433607806664, 'qy': 0.351484917656982, 'cut_dist': 4.017034173791273}. Best is trial 16 with value: 0.08198928651286688.
# 100%|██████████| 102861/102861 [00:51<00:00, 1998.62it/s]
# [I 2025-10-03 22:10:19,278] Trial 18 finished with value: 0.05144320976852257 and parameters: {'noise_x': 18.1033532957855, 'noise_y': 325.92988273787427, 'noise_dx': 2.91244770589699, 'noise_dy': 1.373172361981302, 'qx': 0.24875660333989455, 'qy': 0.3421753665732565, 'cut_dist': 984.5116547996996}. Best is trial 16 with value: 0.08198928651286688.
# 100%|██████████| 102861/102861 [01:27<00:00, 1169.29it/s]
# [I 2025-10-03 22:11:50,199] Trial 19 finished with value: 0.05535139654485179 and parameters: {'noise_x': 42.2300527398186, 'noise_y': 478.7069314915434, 'noise_dx': 3.0294773835284277, 'noise_dy': 0.19928636377119213, 'qx': 0.2638750571086419, 'qy': 0.20257239565606144, 'cut_dist': 442.5640248898293}. Best is trial 16 with value: 0.08198928651286688.
# 100%|██████████| 102861/102861 [01:55<00:00, 893.09it/s]
# [I 2025-10-03 22:13:48,400] Trial 20 finished with value: 0.05695550305752423 and parameters: {'noise_x': 359.37162170969503, 'noise_y': 405.892721849076, 'noise_dx': 2.6549201695939293, 'noise_dy': 1.48687667331365, 'qx': 0.14544941434023462, 'qy': 0.6352297282069368, 'cut_dist': 255.0463248158948}. Best is trial 16 with value: 0.08198928651286688.
# 100%|██████████| 102861/102861 [02:01<00:00, 848.07it/s]
# [I 2025-10-03 22:15:52,976] Trial 21 finished with value: 0.08081294173690709 and parameters: {'noise_x': 152.6911515283094, 'noise_y': 238.86739662345605, 'noise_dx': 2.097044913255061, 'noise_dy': 2.225368823020352, 'qx': 0.34567828228348557, 'qy': 0.40028930100749666, 'cut_dist': 3.2655158793003807}. Best is trial 16 with value: 0.08198928651286688.
# 100%|██████████| 102861/102861 [01:59<00:00, 859.20it/s]
# [I 2025-10-03 22:17:55,973] Trial 22 finished with value: 0.0827427304809403 and parameters: {'noise_x': 154.9105263522005, 'noise_y': 219.18270927044804, 'noise_dx': 3.491000223641734, 'noise_dy': 2.8373398845139457, 'qx': 0.37178234317883474, 'qy': 0.3686951864673841, 'cut_dist': 2.9100108654918317}. Best is trial 22 with value: 0.0827427304809403.
# 100%|██████████| 102861/102861 [00:51<00:00, 1991.07it/s]
# [I 2025-10-03 22:18:50,687] Trial 23 finished with value: 0.06287125343910714 and parameters: {'noise_x': 158.25651555448638, 'noise_y': 245.36484610249283, 'noise_dx': 3.4851576030293754, 'noise_dy': 2.8199680549477533, 'qx': 0.39895341521928407, 'qy': 0.4005523284828306, 'cut_dist': 118.81010759152207}. Best is trial 22 with value: 0.0827427304809403.
# 100%|██████████| 102861/102861 [01:51<00:00, 926.54it/s]
# [I 2025-10-03 22:20:44,784] Trial 24 finished with value: 0.059925530570381386 and parameters: {'noise_x': 159.8202151999352, 'noise_y': 196.69815783852187, 'noise_dx': 3.3294308210940793, 'noise_dy': 3.1051970363560946, 'qx': 0.338718615732995, 'qy': 0.603538303703516, 'cut_dist': 174.15470573138248}. Best is trial 22 with value: 0.0827427304809403.
# 100%|██████████| 102861/102861 [01:52<00:00, 917.50it/s]
# [I 2025-10-03 22:22:39,970] Trial 25 finished with value: 0.06208378296924976 and parameters: {'noise_x': 63.808635700426805, 'noise_y': 236.3692130972605, 'noise_dx': 4.0356365081334005, 'noise_dy': 3.5017676748893343, 'qx': 0.5850778527887562, 'qy': 0.2211145533200963, 'cut_dist': 104.50684819762347}. Best is trial 22 with value: 0.0827427304809403.
# 100%|██████████| 102861/102861 [01:47<00:00, 960.36it/s]
# [I 2025-10-03 22:24:30,023] Trial 26 finished with value: 0.049012745355382505 and parameters: {'noise_x': 218.1298028329423, 'noise_y': 283.7151134152933, 'noise_dx': 2.5652196820694377, 'noise_dy': 2.3734546832967713, 'qx': 0.41842333964601264, 'qy': 0.42710900280887093, 'cut_dist': 839.1705078037166}. Best is trial 22 with value: 0.0827427304809403.
# 100%|██████████| 102861/102861 [01:54<00:00, 897.94it/s]
# [I 2025-10-03 22:26:27,565] Trial 27 finished with value: 0.056683291043252544 and parameters: {'noise_x': 337.3923714544102, 'noise_y': 227.14081844809755, 'noise_dx': 4.821905407451997, 'noise_dy': 1.9952333673944884, 'qx': 0.19080780192565922, 'qy': 0.41827557157229495, 'cut_dist': 240.38402243305822}. Best is trial 22 with value: 0.0827427304809403.
# 100%|██████████| 102861/102861 [01:46<00:00, 962.14it/s]
# [I 2025-10-03 22:28:17,469] Trial 28 finished with value: 0.06381913456023176 and parameters: {'noise_x': 191.4660137884944, 'noise_y': 166.22942300128616, 'noise_dx': 2.386784137168472, 'noise_dy': 2.5814513595425685, 'qx': 0.7187964289622124, 'qy': 0.6013392653712044, 'cut_dist': 87.65679537669705}. Best is trial 22 with value: 0.0827427304809403.
# 100%|██████████| 102861/102861 [01:53<00:00, 910.09it/s]
# [I 2025-10-03 22:30:13,491] Trial 29 finished with value: 0.04697115524834485 and parameters: {'noise_x': 161.48039002193732, 'noise_y': 304.47705091899195, 'noise_dx': 1.9785682045099753, 'noise_dy': 0.9884095339755845, 'qx': 0.4666916132858431, 'qy': 0.0027479156000916327, 'cut_dist': 612.6121919299553}. Best is trial 22 with value: 0.0827427304809403.
# 100%|██████████| 102861/102861 [01:35<00:00, 1074.06it/s]
# [I 2025-10-03 22:31:52,302] Trial 30 finished with value: 0.06057203410427665 and parameters: {'noise_x': 72.1856149886395, 'noise_y': 374.9006777763287, 'noise_dx': 1.0943303147036603, 'noise_dy': 4.282403312123018, 'qx': 0.10421107691156012, 'qy': 0.2676037627437781, 'cut_dist': 328.1488205298174}. Best is trial 22 with value: 0.0827427304809403.
# 100%|██████████| 102861/102861 [02:00<00:00, 851.44it/s]
# [I 2025-10-03 22:33:56,394] Trial 31 finished with value: 0.07613672820602561 and parameters: {'noise_x': 32.64118828649798, 'noise_y': 327.4138081355814, 'noise_dx': 2.8344716859749517, 'noise_dy': 1.8259394946359047, 'qx': 0.32190846281872276, 'qy': 0.328793757054611, 'cut_dist': 18.130797529955203}. Best is trial 22 with value: 0.0827427304809403.
# 100%|██████████| 102861/102861 [02:05<00:00, 822.53it/s]
# [I 2025-10-03 22:36:04,708] Trial 32 finished with value: 0.07964145788977357 and parameters: {'noise_x': 44.64070301508398, 'noise_y': 306.0275519284861, 'noise_dx': 3.2482626781277877, 'noise_dy': 2.997487586875937, 'qx': 0.3309091958128334, 'qy': 0.4380439141836183, 'cut_dist': 3.5846311357114864}. Best is trial 22 with value: 0.0827427304809403.
# 100%|██████████| 102861/102861 [01:45<00:00, 973.72it/s]
# [I 2025-10-03 22:37:53,437] Trial 33 finished with value: 0.05986719942446603 and parameters: {'noise_x': 258.4426108973661, 'noise_y': 220.2323662039962, 'noise_dx': 2.09812025210853, 'noise_dy': 1.2751396530228907, 'qx': 0.44942481825424385, 'qy': 0.5643683613789248, 'cut_dist': 161.74100494155246}. Best is trial 22 with value: 0.0827427304809403.
# 100%|██████████| 102861/102861 [01:55<00:00, 893.28it/s]
# [I 2025-10-03 22:39:51,700] Trial 34 finished with value: 0.06505381048210693 and parameters: {'noise_x': 2.810513360992964, 'noise_y': 257.03713926280574, 'noise_dx': 3.8649658037255112, 'noise_dy': 2.149884272611244, 'qx': 0.5722039542050004, 'qy': 0.28389604162945453, 'cut_dist': 93.44992607786489}. Best is trial 22 with value: 0.0827427304809403.
# 100%|██████████| 102861/102861 [01:30<00:00, 1139.30it/s]
# [I 2025-10-03 22:41:25,180] Trial 35 finished with value: 0.07094039529073215 and parameters: {'noise_x': 93.99241487731989, 'noise_y': 108.23379769300549, 'noise_dx': 2.3799620106476387, 'noise_dy': 0.5307166231656111, 'qx': 0.019067903134627306, 'qy': 0.3741448137915444, 'cut_dist': 52.816933250436364}. Best is trial 22 with value: 0.0827427304809403.
# 100%|██████████| 102861/102861 [01:52<00:00, 912.68it/s]
# [I 2025-10-03 22:43:20,851] Trial 36 finished with value: 0.06253584935009382 and parameters: {'noise_x': 140.90329084462547, 'noise_y': 180.250758686445, 'noise_dx': 3.295767746358369, 'noise_dy': 1.6869167924125161, 'qx': 0.29178674199019816, 'qy': 0.18227319271044348, 'cut_dist': 153.66492071307812}. Best is trial 22 with value: 0.0827427304809403.
# 100%|██████████| 102861/102861 [01:49<00:00, 942.70it/s]
# [I 2025-10-03 22:45:13,017] Trial 37 finished with value: 0.0625407102789201 and parameters: {'noise_x': 240.34402331938134, 'noise_y': 59.63309285087304, 'noise_dx': 2.7132365240935057, 'noise_dy': 3.228978316265523, 'qx': 0.18673506106108512, 'qy': 0.2705804925092101, 'cut_dist': 219.35279842895847}. Best is trial 22 with value: 0.0827427304809403.
# 100%|██████████| 102861/102861 [01:54<00:00, 895.32it/s]
# [I 2025-10-03 22:47:11,017] Trial 38 finished with value: 0.07911161664770905 and parameters: {'noise_x': 82.87546358100553, 'noise_y': 404.8299204394608, 'noise_dx': 0.05583712421318676, 'noise_dy': 2.7478479518679277, 'qx': 0.525141071454607, 'qy': 0.6671721743545215, 'cut_dist': 6.746390182793844}. Best is trial 22 with value: 0.0827427304809403.
# 100%|██████████| 102861/102861 [00:53<00:00, 1917.48it/s]
# [I 2025-10-03 22:48:07,544] Trial 39 finished with value: 0.050573103508618426 and parameters: {'noise_x': 301.8304547312613, 'noise_y': 130.02502492810643, 'noise_dx': 3.71874446865101, 'noise_dy': 1.1152632680001555, 'qx': 0.480497602353934, 'qy': 0.809719180598539, 'cut_dist': 558.8144114062839}. Best is trial 22 with value: 0.0827427304809403.
# 100%|██████████| 102861/102861 [01:43<00:00, 992.36it/s]
# [I 2025-10-03 22:49:54,243] Trial 40 finished with value: 0.06216155783047025 and parameters: {'noise_x': 50.92665243056442, 'noise_y': 83.43747611095195, 'noise_dx': 4.3431942735873434, 'noise_dy': 3.542079144253045, 'qx': 0.36484552082145427, 'qy': 0.3708208762357107, 'cut_dist': 136.4882675498065}. Best is trial 22 with value: 0.0827427304809403.
# 100%|██████████| 102861/102861 [02:07<00:00, 803.74it/s]
# [I 2025-10-03 22:52:05,615] Trial 41 finished with value: 0.09024314365989053 and parameters: {'noise_x': 32.42198827785583, 'noise_y': 302.60195093686036, 'noise_dx': 3.3258533732817486, 'noise_dy': 3.021960762142642, 'qx': 0.30946859560801476, 'qy': 0.45387965413058506, 'cut_dist': 0.29709660736903043}. Best is trial 41 with value: 0.09024314365989053.
# 100%|██████████| 102861/102861 [01:55<00:00, 888.75it/s]
# [I 2025-10-03 22:54:04,439] Trial 42 finished with value: 0.06758635440059886 and parameters: {'noise_x': 25.651609597519652, 'noise_y': 300.94671017846895, 'noise_dx': 3.17402770472836, 'noise_dy': 2.0892172730595546, 'qx': 0.29347003688079587, 'qy': 0.4584714877717101, 'cut_dist': 78.61355553529347}. Best is trial 41 with value: 0.09024314365989053.
# 100%|██████████| 102861/102861 [01:56<00:00, 885.64it/s]
# [I 2025-10-03 22:56:03,680] Trial 43 finished with value: 0.0669398508667036 and parameters: {'noise_x': 109.37241322917143, 'noise_y': 342.31379423435556, 'noise_dx': 3.599147481876237, 'noise_dy': 2.4784077258233363, 'qx': 0.19998687388486253, 'qy': 0.31093488637143724, 'cut_dist': 66.21352429673132}. Best is trial 41 with value: 0.09024314365989053.
# 100%|██████████| 102861/102861 [01:19<00:00, 1297.72it/s]
# [I 2025-10-03 22:57:25,871] Trial 44 finished with value: 0.05675620497564675 and parameters: {'noise_x': 194.98870803551756, 'noise_y': 373.41413383885475, 'noise_dx': 2.1753770539566464, 'noise_dy': 3.7318310865638393, 'qx': 0.4228119671505127, 'qy': 0.5348346274455531, 'cut_dist': 197.14297210154785}. Best is trial 41 with value: 0.09024314365989053.
# 100%|██████████| 102861/102861 [02:05<00:00, 818.35it/s]
# [I 2025-10-03 22:59:34,821] Trial 45 finished with value: 0.07903870271531484 and parameters: {'noise_x': 3.4033305479606373, 'noise_y': 19.591039706295845, 'noise_dx': 1.7789315705141575, 'noise_dy': 3.252518749678348, 'qx': 0.12027381382871416, 'qy': 0.48158479981663427, 'cut_dist': 5.217989677100938}. Best is trial 41 with value: 0.09024314365989053.
# 100%|██████████| 102861/102861 [01:54<00:00, 898.90it/s]
# [I 2025-10-03 23:01:32,495] Trial 46 finished with value: 0.06616696318332507 and parameters: {'noise_x': 132.12092510061444, 'noise_y': 211.08585585432309, 'noise_dx': 2.5473069137601265, 'noise_dy': 2.2636240144872133, 'qx': 0.36847096013639946, 'qy': 0.1174362117045854, 'cut_dist': 61.393823674402846}. Best is trial 41 with value: 0.09024314365989053.
# 100%|██████████| 102861/102861 [01:52<00:00, 915.60it/s]
# [I 2025-10-03 23:03:27,827] Trial 47 finished with value: 0.061709491449626196 and parameters: {'noise_x': 67.53113914455085, 'noise_y': 280.8488243935964, 'noise_dx': 3.978034426589532, 'noise_dy': 1.66356497470586, 'qx': 0.7606089327205856, 'qy': 0.38609994861101693, 'cut_dist': 121.61477216757308}. Best is trial 41 with value: 0.09024314365989053.
# 100%|██████████| 102861/102861 [01:51<00:00, 919.25it/s]
# [I 2025-10-03 23:05:22,641] Trial 48 finished with value: 0.050796706234627315 and parameters: {'noise_x': 25.114424307026326, 'noise_y': 254.70398931725836, 'noise_dx': 4.50597782657961, 'noise_dy': 2.6538354908024306, 'qx': 0.5816291898657413, 'qy': 0.5677681983110028, 'cut_dist': 742.0432632593697}. Best is trial 41 with value: 0.09024314365989053.
# 100%|██████████| 102861/102861 [01:38<00:00, 1045.83it/s]
# [I 2025-10-03 23:07:03,997] Trial 49 finished with value: 0.07116399801674105 and parameters: {'noise_x': 95.12062879805052, 'noise_y': 141.61625895998782, 'noise_dx': 3.4851803770784504, 'noise_dy': 0.7509053117861434, 'qx': 0.27640606563303477, 'qy': 0.706622531457376, 'cut_dist': 51.57852834351055}. Best is trial 41 with value: 0.09024314365989053.
# 100%|██████████| 102861/102861 [01:34<00:00, 1083.96it/s]
# [I 2025-10-03 23:08:41,883] Trial 50 finished with value: 0.057859635819212336 and parameters: {'noise_x': 220.44679316147256, 'noise_y': 196.45513161142978, 'noise_dx': 2.830890152795813, 'noise_dy': 2.870430787229611, 'qx': 0.23747637629931617, 'qy': 0.4594268800064523, 'cut_dist': 264.80503715950636}. Best is trial 41 with value: 0.09024314365989053.
# 100%|██████████| 102861/102861 [02:03<00:00, 835.22it/s]
# [I 2025-10-03 23:10:48,249] Trial 51 finished with value: 0.0796122923168159 and parameters: {'noise_x': 44.642871007441585, 'noise_y': 301.13670034389264, 'noise_dx': 3.1547824300789604, 'noise_dy': 3.039633421012137, 'qx': 0.32816334580878626, 'qy': 0.45445209172722023, 'cut_dist': 5.463238633130544}. Best is trial 41 with value: 0.09024314365989053.
# 100%|██████████| 102861/102861 [01:57<00:00, 874.40it/s]
# [I 2025-10-03 23:12:48,913] Trial 52 finished with value: 0.0704640242657567 and parameters: {'noise_x': 55.40100431861558, 'noise_y': 343.34282859870416, 'noise_dx': 3.0235411542945716, 'noise_dy': 3.35578722521177, 'qx': 0.31558577367057905, 'qy': 0.5385854054554214, 'cut_dist': 36.41097631827532}. Best is trial 41 with value: 0.09024314365989053.
# 100%|██████████| 102861/102861 [02:05<00:00, 819.19it/s]
# [I 2025-10-03 23:14:57,715] Trial 53 finished with value: 0.08070600130272892 and parameters: {'noise_x': 37.912717808588326, 'noise_y': 319.23363678880514, 'noise_dx': 3.3795271042146307, 'noise_dy': 3.066877616808383, 'qx': 0.35579808704730825, 'qy': 0.35845327046034814, 'cut_dist': 3.1690177932328036}. Best is trial 41 with value: 0.09024314365989053.
# 100%|██████████| 102861/102861 [01:53<00:00, 906.26it/s]
# [I 2025-10-03 23:16:54,273] Trial 54 finished with value: 0.06400871078445669 and parameters: {'noise_x': 15.274989688035628, 'noise_y': 328.25672625104335, 'noise_dx': 3.7765188951170314, 'noise_dy': 4.063833136588894, 'qx': 0.38134120514940173, 'qy': 0.3694606112275663, 'cut_dist': 120.67368972720507}. Best is trial 41 with value: 0.09024314365989053.
# 100%|██████████| 102861/102861 [01:49<00:00, 941.92it/s]
# [I 2025-10-03 23:18:46,453] Trial 55 finished with value: 0.06599683067440526 and parameters: {'noise_x': 85.23599806373196, 'noise_y': 369.49204700764363, 'noise_dx': 3.401655888755217, 'noise_dy': 2.509898115199393, 'qx': 0.445314974469897, 'qy': 0.9466343920582898, 'cut_dist': 57.497212014929055}. Best is trial 41 with value: 0.09024314365989053.
# 100%|██████████| 102861/102861 [01:53<00:00, 905.22it/s]
# [I 2025-10-03 23:20:43,009] Trial 56 finished with value: 0.05430629684720156 and parameters: {'noise_x': 499.0537374515786, 'noise_y': 267.8945222015967, 'noise_dx': 2.337840347064219, 'noise_dy': 2.8099455429904703, 'qx': 0.5287695448505927, 'qy': 0.2337573528392049, 'cut_dist': 194.88339112010212}. Best is trial 41 with value: 0.09024314365989053.
# 100%|██████████| 102861/102861 [01:45<00:00, 976.45it/s]
# [I 2025-10-03 23:22:31,409] Trial 57 finished with value: 0.06406218100154577 and parameters: {'noise_x': 175.7675397521628, 'noise_y': 403.1742133211652, 'noise_dx': 2.7445561561701184, 'noise_dy': 2.2397423710671225, 'qx': 0.6780195270693741, 'qy': 0.3147527959041914, 'cut_dist': 96.38912393623406}. Best is trial 41 with value: 0.09024314365989053.
# 100%|██████████| 102861/102861 [01:17<00:00, 1326.45it/s]
# [I 2025-10-03 23:23:52,154] Trial 58 finished with value: 0.06925365298801295 and parameters: {'noise_x': 110.16380067554593, 'noise_y': 238.77423478028575, 'noise_dx': 3.036758629390075, 'noise_dy': 3.1423946480029956, 'qx': 0.4937634704021352, 'qy': 0.40100033881467634, 'cut_dist': 33.94975656137907}. Best is trial 41 with value: 0.09024314365989053.
# 100%|██████████| 102861/102861 [01:49<00:00, 940.84it/s]
# [I 2025-10-03 23:25:44,581] Trial 59 finished with value: 0.059784563634419266 and parameters: {'noise_x': 142.3060779566663, 'noise_y': 454.082454074477, 'noise_dx': 4.090831759777211, 'noise_dy': 1.8958152195969566, 'qx': 0.21473591481178345, 'qy': 0.5099489535551359, 'cut_dist': 157.81015741616696}. Best is trial 41 with value: 0.09024314365989053.
# 100%|██████████| 102861/102861 [01:50<00:00, 930.66it/s]
# [I 2025-10-03 23:27:38,120] Trial 60 finished with value: 0.04716073147256978 and parameters: {'noise_x': 275.45732833172104, 'noise_y': 183.43123974088965, 'noise_dx': 3.5667013068855082, 'noise_dy': 3.578433327731264, 'qx': 0.3552983166776683, 'qy': 0.16276782497631792, 'cut_dist': 920.7731418730755}. Best is trial 41 with value: 0.09024314365989053.
# 100%|██████████| 102861/102861 [01:56<00:00, 881.56it/s]
# [I 2025-10-03 23:29:37,839] Trial 61 finished with value: 0.07387153537297907 and parameters: {'noise_x': 35.73103043480665, 'noise_y': 312.82420694365135, 'noise_dx': 3.178508686935738, 'noise_dy': 2.921215230408415, 'qx': 0.2576693475843313, 'qy': 0.4269744882282844, 'cut_dist': 27.946959229566684}. Best is trial 41 with value: 0.09024314365989053.
# 100%|██████████| 102861/102861 [01:44<00:00, 984.16it/s]
# [I 2025-10-03 23:31:25,354] Trial 62 finished with value: 0.06311916080924743 and parameters: {'noise_x': 52.44385287078573, 'noise_y': 286.8701361524332, 'noise_dx': 3.3531897341351793, 'noise_dy': 2.618668848211324, 'qx': 0.40163117439148444, 'qy': 0.34262641558989204, 'cut_dist': 87.18176063558342}. Best is trial 41 with value: 0.09024314365989053.
# 100%|██████████| 102861/102861 [01:52<00:00, 913.17it/s]
# [I 2025-10-03 23:33:26,168] Trial 63 finished with value: 0.08201845208582456 and parameters: {'noise_x': 22.55389721419012, 'noise_y': 355.7568686710083, 'noise_dx': 2.9345800962697774, 'noise_dy': 3.1131705889007106, 'qx': 0.1651091016599069, 'qy': 0.45700716635334826, 'cut_dist': 6.809744469695529}. Best is trial 41 with value: 0.09024314365989053.
# 100%|██████████| 102861/102861 [01:02<00:00, 1638.47it/s]
# [I 2025-10-03 23:34:32,201] Trial 64 finished with value: 0.08436141978009158 and parameters: {'noise_x': 11.047072787987258, 'noise_y': 357.2992851217115, 'noise_dx': 2.9296872346030156, 'noise_dy': 3.7638069203145395, 'qx': 0.14480535940108163, 'qy': 0.6040112070816143, 'cut_dist': 1.8764388942319767}. Best is trial 41 with value: 0.09024314365989053.
# 100%|██████████| 102861/102861 [01:52<00:00, 914.01it/s]
# [I 2025-10-03 23:36:27,699] Trial 65 finished with value: 0.05766033773733485 and parameters: {'noise_x': 15.742824053888043, 'noise_y': 348.6111514404642, 'noise_dx': 2.611767470169511, 'noise_dy': 3.791984026916678, 'qx': 0.06532210814690632, 'qy': 0.6325266194837765, 'cut_dist': 441.9258258918908}. Best is trial 41 with value: 0.09024314365989053.
# 100%|██████████| 102861/102861 [01:49<00:00, 937.06it/s]
# [I 2025-10-03 23:38:20,540] Trial 66 finished with value: 0.06765440740416678 and parameters: {'noise_x': 414.0352092915067, 'noise_y': 383.7685522128006, 'noise_dx': 1.770273590053974, 'noise_dy': 4.998168523176553, 'qx': 0.1736358130276277, 'qy': 0.5562702944019359, 'cut_dist': 40.448498873873774}. Best is trial 41 with value: 0.09024314365989053.
# 100%|██████████| 102861/102861 [01:43<00:00, 991.41it/s]
# [I 2025-10-03 23:40:07,268] Trial 67 finished with value: 0.0650343667668018 and parameters: {'noise_x': 64.9540497045959, 'noise_y': 422.3142665288865, 'noise_dx': 2.8373112807710816, 'noise_dy': 3.359919852474654, 'qx': 0.15650205211208632, 'qy': 0.6047967348484239, 'cut_dist': 125.60814278094689}. Best is trial 41 with value: 0.09024314365989053.
# 100%|██████████| 102861/102861 [01:56<00:00, 884.00it/s]
# [I 2025-10-03 23:42:06,757] Trial 68 finished with value: 0.06474757196605127 and parameters: {'noise_x': 29.37018883428035, 'noise_y': 358.28078789878066, 'noise_dx': 2.4480386150003293, 'noise_dy': 4.380848873013225, 'qx': 0.05455973727370596, 'qy': 0.4844833654616518, 'cut_dist': 74.56820576009054}. Best is trial 41 with value: 0.09024314365989053.
# 100%|██████████| 102861/102861 [00:54<00:00, 1888.02it/s]
# [I 2025-10-03 23:43:04,274] Trial 69 finished with value: 0.07094039529073215 and parameters: {'noise_x': 1.3641327304912814, 'noise_y': 391.08212356619754, 'noise_dx': 2.9617093849909435, 'noise_dy': 4.536615529115425, 'qx': 0.11775801672664626, 'qy': 0.6572476455064848, 'cut_dist': 27.424581526821527}. Best is trial 41 with value: 0.09024314365989053.
# 100%|██████████| 102861/102861 [01:52<00:00, 912.73it/s]
# [I 2025-10-03 23:45:00,084] Trial 70 finished with value: 0.06585586373844314 and parameters: {'noise_x': 79.40585738447712, 'noise_y': 331.1889147319099, 'noise_dx': 2.248243453854392, 'noise_dy': 3.74275008644373, 'qx': 0.6143811970105347, 'qy': 0.7742518419377568, 'cut_dist': 103.4185436211778}. Best is trial 41 with value: 0.09024314365989053.
# 100%|██████████| 102861/102861 [01:58<00:00, 870.93it/s]
# [I 2025-10-03 23:47:01,309] Trial 71 finished with value: 0.08009838519944391 and parameters: {'noise_x': 12.817001924422483, 'noise_y': 317.45002236378804, 'noise_dx': 3.0913811476991926, 'noise_dy': 4.001954998108067, 'qx': 0.3028156605853725, 'qy': 0.35394122845071624, 'cut_dist': 8.100392036466598}. Best is trial 41 with value: 0.09024314365989053.
# 100%|██████████| 102861/102861 [01:58<00:00, 864.93it/s]
# [I 2025-10-03 23:49:03,435] Trial 72 finished with value: 0.0815177764167177 and parameters: {'noise_x': 35.063505391484846, 'noise_y': 361.83626856324656, 'noise_dx': 1.2147840648570276, 'noise_dy': 3.133272049118329, 'qx': 0.2465989195176626, 'qy': 0.3996180284015271, 'cut_dist': 3.6306945356140785}. Best is trial 41 with value: 0.09024314365989053.
# 100%|██████████| 102861/102861 [01:56<00:00, 885.09it/s]
# [I 2025-10-03 23:51:02,798] Trial 73 finished with value: 0.06933628877805971 and parameters: {'noise_x': 37.77182926728972, 'noise_y': 359.8987137398819, 'noise_dx': 1.2039677146456846, 'noise_dy': 3.137199563801514, 'qx': 0.2360683318180238, 'qy': 0.411580212731263, 'cut_dist': 56.63061681383243}. Best is trial 41 with value: 0.09024314365989053.
# 100%|██████████| 102861/102861 [02:06<00:00, 811.82it/s]
# [I 2025-10-03 23:53:12,717] Trial 74 finished with value: 0.08147888898610746 and parameters: {'noise_x': 55.75978113126874, 'noise_y': 437.2882202768417, 'noise_dx': 0.43486596561073654, 'noise_dy': 2.3827999745024573, 'qx': 0.8649928442457019, 'qy': 0.5093478873284177, 'cut_dist': 1.74032304492639}. Best is trial 41 with value: 0.09024314365989053.
# 100%|██████████| 102861/102861 [01:40<00:00, 1026.74it/s]
# [I 2025-10-03 23:54:56,065] Trial 75 finished with value: 0.06550587686295098 and parameters: {'noise_x': 56.595882620305275, 'noise_y': 453.38202742719795, 'noise_dx': 0.6672458609963225, 'noise_dy': 2.3797111657397347, 'qx': 0.8611111275564589, 'qy': 0.515246292166396, 'cut_dist': 77.1242796353117}. Best is trial 41 with value: 0.09024314365989053.
# 100%|██████████| 102861/102861 [01:40<00:00, 1027.40it/s]
# [I 2025-10-03 23:56:39,189] Trial 76 finished with value: 0.0713681570274448 and parameters: {'noise_x': 95.56945588394018, 'noise_y': 427.35791655131936, 'noise_dx': 0.22716161588015332, 'noise_dy': 3.253676472351641, 'qx': 0.9261272462144894, 'qy': 0.5782601672935483, 'cut_dist': 29.71284830907437}. Best is trial 41 with value: 0.09024314365989053.
# 100%|██████████| 102861/102861 [01:46<00:00, 964.65it/s]
# [I 2025-10-03 23:58:28,805] Trial 77 finished with value: 0.060489398314229885 and parameters: {'noise_x': 28.041381245138982, 'noise_y': 459.5298406178068, 'noise_dx': 0.6130023454147738, 'noise_dy': 2.728501843450543, 'qx': 0.9968071143227721, 'qy': 0.4787887578680382, 'cut_dist': 140.9687915526388}. Best is trial 41 with value: 0.09024314365989053.
# 100%|██████████| 102861/102861 [01:35<00:00, 1078.45it/s]
# [I 2025-10-04 00:00:07,227] Trial 78 finished with value: 0.06388718756379969 and parameters: {'noise_x': 1.3602529207719272, 'noise_y': 490.4612763378404, 'noise_dx': 1.265333509656887, 'noise_dy': 2.940273460270083, 'qx': 0.8138641647969695, 'qy': 0.44786087620207105, 'cut_dist': 102.04013727982513}. Best is trial 41 with value: 0.09024314365989053.
# 100%|██████████| 102861/102861 [01:39<00:00, 1029.41it/s]
# [I 2025-10-04 00:01:50,266] Trial 79 finished with value: 0.07135843516979225 and parameters: {'noise_x': 65.71144982002079, 'noise_y': 290.8967495558677, 'noise_dx': 0.9063068969264043, 'noise_dy': 2.51704979834856, 'qx': 0.14202254323372443, 'qy': 0.524287458942546, 'cut_dist': 45.80534445237812}. Best is trial 41 with value: 0.09024314365989053.
# 100%|██████████| 102861/102861 [01:54<00:00, 902.02it/s]
# [I 2025-10-04 00:03:47,373] Trial 80 finished with value: 0.06742594374933163 and parameters: {'noise_x': 128.34220220346657, 'noise_y': 226.1672099590042, 'noise_dx': 1.4291738507000638, 'noise_dy': 3.451744237602831, 'qx': 0.09318293299477776, 'qy': 0.5974600393722042, 'cut_dist': 74.99837157935251}. Best is trial 41 with value: 0.09024314365989053.
# 100%|██████████| 102861/102861 [01:37<00:00, 1049.72it/s]
# [I 2025-10-04 00:05:28,608] Trial 81 finished with value: 0.0841864263423455 and parameters: {'noise_x': 45.93375045114675, 'noise_y': 151.98727313394272, 'noise_dx': 0.46840552631906524, 'noise_dy': 3.0569898866395815, 'qx': 0.21626164210822774, 'qy': 0.29906809034141424, 'cut_dist': 3.282444854710453}. Best is trial 41 with value: 0.09024314365989053.
# 100%|██████████| 102861/102861 [01:21<00:00, 1255.89it/s]
# [I 2025-10-04 00:06:54,535] Trial 82 finished with value: 0.09911919969667804 and parameters: {'noise_x': 22.195064701927237, 'noise_y': 154.08952512813164, 'noise_dx': 0.4982923714732202, 'noise_dy': 2.720219440238446, 'qx': 0.20623593765872372, 'qy': 0.3086024924849269, 'cut_dist': 0.05591755755046912}. Best is trial 82 with value: 0.09911919969667804.
# 100%|██████████| 102861/102861 [02:02<00:00, 836.68it/s]
# [I 2025-10-04 00:09:00,726] Trial 83 finished with value: 0.07593743012414812 and parameters: {'noise_x': 20.342006199730214, 'noise_y': 154.27876662097844, 'noise_dx': 0.40216991159752724, 'noise_dy': 2.7314560915837975, 'qx': 0.2113698189671504, 'qy': 0.26797702300576, 'cut_dist': 26.88585569881405}. Best is trial 82 with value: 0.09911919969667804.
# 100%|██████████| 102861/102861 [01:58<00:00, 870.40it/s]
# [I 2025-10-04 00:11:02,131] Trial 84 finished with value: 0.07280213103119744 and parameters: {'noise_x': 44.88803549963268, 'noise_y': 113.88033351637648, 'noise_dx': 0.5104914465843848, 'noise_dy': 2.8508461667519107, 'qx': 0.1647128079253909, 'qy': 0.24718913628539085, 'cut_dist': 55.189582704312095}. Best is trial 82 with value: 0.09911919969667804.
# 100%|██████████| 102861/102861 [01:58<00:00, 870.45it/s]
# [I 2025-10-04 00:13:03,618] Trial 85 finished with value: 0.07322989276791009 and parameters: {'noise_x': 14.04315339634503, 'noise_y': 101.93754856536435, 'noise_dx': 0.9252995261976609, 'noise_dy': 3.1947587913945044, 'qx': 0.2693499529575579, 'qy': 0.3139506802441677, 'cut_dist': 25.015194982142262}. Best is trial 82 with value: 0.09911919969667804.
# 100%|██████████| 102861/102861 [01:57<00:00, 876.02it/s]
# [I 2025-10-04 00:15:04,537] Trial 86 finished with value: 0.08632523502590875 and parameters: {'noise_x': 75.28334293945323, 'noise_y': 153.61660614792956, 'noise_dx': 0.09325447296741451, 'noise_dy': 2.376887271241232, 'qx': 0.21804387909443368, 'qy': 0.3853360971577939, 'cut_dist': 2.2156729465239717}. Best is trial 82 with value: 0.09911919969667804.
# 100%|██████████| 102861/102861 [01:56<00:00, 880.48it/s]
# [I 2025-10-04 00:17:04,574] Trial 87 finished with value: 0.07126121659326665 and parameters: {'noise_x': 77.02173406499918, 'noise_y': 147.4381254437906, 'noise_dx': 0.0018287056792756218, 'noise_dy': 3.042513634565193, 'qx': 0.1885289027965793, 'qy': 0.305720063968389, 'cut_dist': 70.18062219024344}. Best is trial 82 with value: 0.09911919969667804.
# 100%|██████████| 102861/102861 [01:54<00:00, 896.31it/s]
# [I 2025-10-04 00:19:02,441] Trial 88 finished with value: 0.05727632436005872 and parameters: {'noise_x': 32.059383068867525, 'noise_y': 169.19755866529889, 'noise_dx': 0.208007840320368, 'noise_dy': 2.625187789363641, 'qx': 0.22361510550589705, 'qy': 0.39487967628760146, 'cut_dist': 660.6676114476859}. Best is trial 82 with value: 0.09911919969667804.
# 100%|██████████| 102861/102861 [01:58<00:00, 864.71it/s]
# [I 2025-10-04 00:21:04,575] Trial 89 finished with value: 0.07394931023419955 and parameters: {'noise_x': 44.005102761478696, 'noise_y': 179.5856878497078, 'noise_dx': 0.17293614667987567, 'noise_dy': 3.576053572151025, 'qx': 0.1277221936902196, 'qy': 0.20652004360170587, 'cut_dist': 43.293335788978574}. Best is trial 82 with value: 0.09911919969667804.
# 100%|██████████| 102861/102861 [01:47<00:00, 954.82it/s]
# [I 2025-10-04 00:22:55,401] Trial 90 finished with value: 0.06646347984172815 and parameters: {'noise_x': 90.31851589363706, 'noise_y': 137.02264214039548, 'noise_dx': 0.3220340762748887, 'noise_dy': 2.9419455976591187, 'qx': 0.2461187277214724, 'qy': 0.28984403537578657, 'cut_dist': 107.75480045455184}. Best is trial 82 with value: 0.09911919969667804.
# 100%|██████████| 102861/102861 [02:03<00:00, 832.77it/s]
# [I 2025-10-04 00:25:02,173] Trial 91 finished with value: 0.08752102351717367 and parameters: {'noise_x': 58.068073179776604, 'noise_y': 129.01886692589824, 'noise_dx': 0.5177593816642583, 'noise_dy': 2.3751091276581335, 'qx': 0.09295975948882261, 'qy': 0.4317002299784004, 'cut_dist': 2.309009806992732}. Best is trial 82 with value: 0.09911919969667804.
# 100%|██████████| 102861/102861 [02:12<00:00, 778.95it/s]
# [I 2025-10-04 00:27:17,520] Trial 92 finished with value: 0.09160906466007525 and parameters: {'noise_x': 102.40075487197608, 'noise_y': 127.59708496525889, 'noise_dx': 0.8443420555607635, 'noise_dy': 2.0050425852409792, 'qx': 0.07434735155602198, 'qy': 0.43022237531998153, 'cut_dist': 0.9504909685507901}. Best is trial 82 with value: 0.09911919969667804.
# 100%|██████████| 102861/102861 [02:01<00:00, 845.39it/s]
# [I 2025-10-04 00:29:22,395] Trial 93 finished with value: 0.07052721634049834 and parameters: {'noise_x': 105.80800217855763, 'noise_y': 130.309355571881, 'noise_dx': 0.6992218089855688, 'noise_dy': 1.9910462350540987, 'qx': 0.015593136353100015, 'qy': 0.42848150063241236, 'cut_dist': 34.400993038735585}. Best is trial 82 with value: 0.09911919969667804.
# 100%|██████████| 102861/102861 [02:22<00:00, 722.98it/s]
# [I 2025-10-04 00:31:48,097] Trial 94 finished with value: 0.09265416435772547 and parameters: {'noise_x': 69.51201695772907, 'noise_y': 90.06786451259754, 'noise_dx': 0.8819958259608884, 'noise_dy': 2.1051763184682226, 'qx': 0.09300346459858676, 'qy': 0.4695979386693323, 'cut_dist': 0.36473436116904034}. Best is trial 82 with value: 0.09911919969667804.
# 100%|██████████| 102861/102861 [01:57<00:00, 874.66it/s]
# [I 2025-10-04 00:33:48,739] Trial 95 finished with value: 0.07313753512021078 and parameters: {'noise_x': 69.964344741275, 'noise_y': 82.60878405418678, 'noise_dx': 0.7936202899853935, 'noise_dy': 2.2024072178330756, 'qx': 0.06150171840496162, 'qy': 0.4582991011053919, 'cut_dist': 57.35933423076452}. Best is trial 82 with value: 0.09911919969667804.
# 100%|██████████| 102861/102861 [01:59<00:00, 858.32it/s]
# [I 2025-10-04 00:35:51,818] Trial 96 finished with value: 0.07781374865109225 and parameters: {'noise_x': 80.21260696981868, 'noise_y': 102.94080269687785, 'noise_dx': 0.9447174387981547, 'noise_dy': 1.7601381794773245, 'qx': 0.033898241895509204, 'qy': 0.38117714269997716, 'cut_dist': 22.191172027464486}. Best is trial 82 with value: 0.09911919969667804.
# 100%|██████████| 102861/102861 [02:00<00:00, 856.29it/s]
# [I 2025-10-04 00:37:55,015] Trial 97 finished with value: 0.07063901770350278 and parameters: {'noise_x': 102.4481084453096, 'noise_y': 92.31702080005026, 'noise_dx': 0.548543507647147, 'noise_dy': 2.2944967367731994, 'qx': 0.0944764612626706, 'qy': 0.3271390529777282, 'cut_dist': 89.89476966181229}. Best is trial 82 with value: 0.09911919969667804.
# 100%|██████████| 102861/102861 [01:38<00:00, 1042.41it/s]
# [I 2025-10-04 00:39:36,853] Trial 98 finished with value: 0.06545726757468817 and parameters: {'noise_x': 62.81054141811385, 'noise_y': 48.87608027888503, 'noise_dx': 0.33859200723027894, 'noise_dy': 2.0592297361801815, 'qx': 0.077318775315086, 'qy': 0.47357398689595503, 'cut_dist': 183.7992952941634}. Best is trial 82 with value: 0.09911919969667804.
# 100%|██████████| 102861/102861 [02:04<00:00, 826.17it/s]
# [I 2025-10-04 00:41:44,571] Trial 99 finished with value: 0.077288768337854 and parameters: {'noise_x': 54.225704932927115, 'noise_y': 121.27348665570655, 'noise_dx': 0.12025869881212808, 'noise_dy': 1.9249888391382313, 'qx': 0.13643858005777507, 'qy': 0.43211224124479064, 'cut_dist': 22.842903133102396}. Best is trial 82 with value: 0.09911919969667804.

# %%
pt.max(track_id)
# Out:
# tensor(11596)

# %%
tids = track_id.numpy()
pids = data["point_id"]

pd.DataFrame({"point_id": pids, "track_id": tids}).to_csv("grademe.csv")
